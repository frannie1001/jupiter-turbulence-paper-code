# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.set_option('mode.chained_assignment', None)
warnings.simplefilter("ignore", category=RuntimeWarning)

import random
import os
from juno_classes import *

from scipy.integrate import trapz

import matplotlib.colors
from matplotlib.cm import ScalarMappable



def extract_base_exponent_scientific(number):
    # Calculate exponent with respect to base 10
    exponent = int(np.log10(number))
    base = number / (10 ** exponent)
    return base, exponent

# %%
def mean_field_align(data_df, window_size=10):
    """Rotate magnetometer data into a mean-field-aligned coordinate system.
        Using the methods described by Khurana & Kivelson[1989]

    Parameters
    ----------
    window_size : int, optional
        The size of the window in minutes that is moved over data to average over.
            This should be EVEN to ensure times of MFA and regular data line up.
            The default is 24.

    Returns
    -------
    None.

    """
    # A windows of size 'window_size' in minutes is then moved along the data
    # An average inside of the window is found for each entry
    #print(self.data_df)
    mean_mag_data = pd.DataFrame({'MEAN_BX': [], 'MEAN_BY': [], 'MEAN_BZ': []})
    finish_datetime = (data_df.index[-1]
    - timedelta(minutes=np.floor(window_size/2)))
    for datetime_index in data_df.index:
        start_datetime = datetime_index
        end_datetime = start_datetime + timedelta(minutes=window_size)
        mean_datetime_index = pd.DatetimeIndex([
            (start_datetime + timedelta(minutes=round(window_size/2))).isoformat()
        ])
        temp_mean = data_df[start_datetime.isoformat(): end_datetime.isoformat()].mean()
        mean_array_to_concat = pd.DataFrame(
            {'MEAN_BX': temp_mean.BX_JSS,
                'MEAN_BY': temp_mean.BY_JSS,
                'MEAN_BZ': temp_mean.BZ_JSS}, index=mean_datetime_index)
        mean_mag_data = pd.concat([mean_mag_data, mean_array_to_concat])
        
        if mean_datetime_index == finish_datetime:
            break
    # mean_mag_data and data_df are cut to align the time series of each
    # mag_data loses half of the time_window in the front
    # mean_mag_data loses half of the time window in the end
    # The two dataframes are then concatenated into one for simplicity
    #data_df = data_df.drop(data_df[: (data_df.index[0] +
    #     timedelta(minutes=round(window_size / 2) - 1)
    # ).isoformat()].index)
    




    data_df = data_df[mean_mag_data.index[0].isoformat(): 
                                mean_mag_data.index[-1].isoformat()]
    data_df = pd.concat([data_df, mean_mag_data], axis=1)
    del mean_mag_data

    # The perturbation components of the mean field are found.

    return data_df

def mean_changer(df):
    mean_x = df['MEAN_BX']
    mean_y = df['MEAN_BY']
    mean_z = df['MEAN_BZ']
    raw_x = df['BX_JSS']
    raw_y = df['BY_JSS']
    raw_z = df['BZ_JSS']
        
    mean_vecs = df[['MEAN_BX', 'MEAN_BY', 'MEAN_BZ']]
    mean_magnitude = np.sqrt((mean_vecs**2).sum(axis=1))

    
    perturbed_x = raw_x - mean_x
    perturbed_y = raw_y - mean_y
    perturbed_z = raw_z - mean_z
    
    perturbed_df = pd.DataFrame({'B_x_pert': perturbed_x, 'B_y_pert': perturbed_y, 'B_z_pert': perturbed_z})
    perturbed_df_perp = pd.DataFrame({'B_x_pert_perp': [], 'B_y_pert_perp': [], 'B_z_pert_perp': []})
    perturbed_df_par = pd.DataFrame({'B_x_pert_par': [], 'B_y_pert_par': [], 'B_z_pert_par': []})
    par_mag_df = pd.DataFrame({'B_pert_par': []})
                                    
    for i in range(len(perturbed_x)):
        new_df_index = pd.DatetimeIndex([df.index[i].isoformat()])
        mean_vecs = df[['MEAN_BX', 'MEAN_BY', 'MEAN_BZ']]
        parallel_hat = mean_vecs.iloc[i] / mean_magnitude[i]
        perturbed_parallel_mag = np.dot((perturbed_df.iloc[i].to_numpy()), parallel_hat)
        perturbed_parallel_vector = np.asarray(perturbed_parallel_mag*parallel_hat)
        perturbed_par_x = perturbed_parallel_vector[0]
        perturbed_par_y = perturbed_parallel_vector[1]
        perturbed_par_z = perturbed_parallel_vector[2]
        perturbed_perp_x = perturbed_df.iloc[i]['B_x_pert'] - perturbed_par_x
        perturbed_perp_y = perturbed_df.iloc[i]['B_y_pert'] - perturbed_par_y
        perturbed_perp_z = perturbed_df.iloc[i]['B_z_pert'] - perturbed_par_z
        
        
        perturbed_df_perp = pd.concat([perturbed_df_perp,pd.DataFrame({'B_x_pert_perp': perturbed_perp_x, 'B_y_pert_perp': perturbed_perp_y, 'B_z_pert_perp': perturbed_perp_z},
                             index=new_df_index)])
    
        perturbed_df_par = pd.concat([perturbed_df_par, pd.DataFrame({'B_x_pert_par': perturbed_par_x, 'B_y_pert_par': perturbed_par_y, 'B_z_pert_par': perturbed_par_z},
                        index=new_df_index) ])
        
        par_mag_df = pd.concat([par_mag_df,         pd.DataFrame({'B_pert_par': perturbed_parallel_mag},
                        index=new_df_index)])
        
    data_df = pd.concat([df, perturbed_df_perp], axis=1)
    data_df  = pd.concat([data_df, perturbed_df_par], axis=1)
    data_df = pd.concat([data_df, par_mag_df], axis = 1)
    return data_df

# %%
startOrbit = 20
endOrbit = 20

for i in range(startOrbit, endOrbit+1):
    print('grabbing orbit ' + str(i))
    #filename = '/home/mtfranciscovich/Juno-codes/reduced_inbound_1s_pickles_unit_z_mag/reduced_orbit_' +str(i)+'_1s.pkl'
    filename = '/home/mtfranciscovich/Juno-codes/fits_u_cart_pickles_updated_vip4/u_cart_orbit_'+str(i)+'.pkl'
    picklefile = open(filename,'rb')
    rawdata = pickle.load(picklefile)
    print(rawdata.columns)
    
    #print('grabbing mean v orbit ' + str(i))
    #filename = '/home/mtfranciscovich/Juno-codes/test_fits_u_cart_means_4min/u_cart_means_4min_orbit_' +str(i) +'.pkl'
    #filename = '/home/mtfranciscovich/Juno-codes/fits_u_cart_pickles_updated/u_cart_orbit_' +str(i)+'.pkl'
    #picklefile = open(filename,'rb')
    #mean_v_data = pickle.load(picklefile)
    
    
    #downsampled = pd.concat([rawdata, mean_v_data.dropna()], axis=1) 
    
    
    
    #downsampled = downsampled.dropna()
    
    print('mean field...')
    #meandata = mean_field_align(downsampled)
    meandata = mean_field_align(rawdata)
    print('running mean changer...')
    final_df = mean_changer(meandata)
    final_df.to_pickle('/home/mtfranciscovich/Juno-codes/testing_means/orbit_'+str(i)+'_1s.pkl')

# %%
def delta_densities(fits_df,window_size = 10):
    
    amu = 1.67*10**-27
    
    m16 = 24*amu
    mo2 = 16*amu
    ms = 32*amu
    ms3 = 32*amu
    
    n_raw = fits_df['      "n"']
    m16_raw = fits_df['r[MQ16]']
    mo_raw = fits_df['r[O2+]']
    ms_raw = fits_df['r[S+]']
    ms3_raw = fits_df['r[S3+]']

    mean_density_data = pd.DataFrame({'MEAN_n': [], 'MEAN_mass': [], 'MEAN_density': [], 'MEAN_temperature': []})
    finish_datetime = (fits_df.index[-1]
    - timedelta(minutes=np.floor(window_size/2)))
    for datetime_index in fits_df.index:
        start_datetime = datetime_index
        end_datetime = start_datetime + timedelta(minutes=window_size)
        mean_datetime_index = pd.DatetimeIndex([
            (start_datetime + timedelta(minutes=round(window_size/2))).isoformat()
        ])
        
        check_array = n_raw[start_datetime.isoformat(): end_datetime.isoformat()].dropna()
        
        if len(check_array) < 4:
            
            continue
        temp_mean_n = np.nanmean(n_raw[start_datetime.isoformat(): end_datetime.isoformat()])
        temp_mean_m16 = np.nanmean(m16_raw[start_datetime.isoformat(): end_datetime.isoformat()])*m16
        temp_mean_mo = np.nanmean(mo_raw[start_datetime.isoformat(): end_datetime.isoformat()])*mo2
        temp_mean_ms = np.nanmean(ms_raw[start_datetime.isoformat(): end_datetime.isoformat()])*ms
        temp_mean_ms3 = np.nanmean(ms3_raw[start_datetime.isoformat(): end_datetime.isoformat()])*ms3
        
        temp_mean_mass = temp_mean_m16+temp_mean_mo+temp_mean_ms+temp_mean_ms3
        temp_mean_density = temp_mean_n*temp_mean_mass
        
        temp_mean_temperature = np.nanmean(fits_df['    "T"'][start_datetime.isoformat(): end_datetime.isoformat()])


        mean_array_to_concat = pd.DataFrame(
            {'MEAN_n': temp_mean_n,
                'MEAN_mass': temp_mean_mass,
                'MEAN_density': temp_mean_density,
            'MEAN_temperature': temp_mean_temperature},
            
            index=mean_datetime_index)
        mean_density_data = pd.concat([mean_density_data, mean_array_to_concat])
        
        if mean_datetime_index == finish_datetime:
            break
    # mean_mag_data and data_df are cut to align the time series of each
    # mag_data loses half of the time_window in the front
    # mean_mag_data loses half of the time window in the end
    # The two dataframes are then concatenated into one for simplicity
    #data_df = data_df.drop(data_df[: (data_df.index[0] +
    #     timedelta(minutes=round(window_size / 2) - 1)
    # ).isoformat()].index)
    




    fits_df = fits_df[mean_density_data.index[0].isoformat(): 
                                mean_density_data.index[-1].isoformat()]
    fits_df = pd.concat([fits_df, mean_density_data], axis=1)
    
    print('density_mean_df made, looking at perts...')
    del mean_density_data
    

    # The perturbation components of the mean field are found.
    # The method used is described in Khurana & Kivelson 1989
    
    
    #mean_mag_vecs = mag_data_df[['MEAN_BX', 'MEAN_BY', 'MEAN_BZ']]
    #mean_mag_magnitude = np.sqrt((mean_mag_vecs**2).sum(axis=1))
    
    
    
    mean_density = fits_df['MEAN_density']
    raw_density = n_raw* ( m16_raw*m16+mo_raw*mo2+ms_raw*ms + ms3_raw*ms3)

    
    perturbed_density = raw_density - mean_density

    
    perturbed_density_df = pd.DataFrame({'density_pert': perturbed_density})

    

            
    data_df = pd.concat([fits_df, perturbed_density_df], axis=1)

    return data_df

# %%
def mean_field_align_v_new(mag_data_df, v_data_df, window_size=10):
    v_data_df = v_data_df.dropna()
    """Rotate magnetometer data into a mean-field-aligned coordinate system.
        Using the methods described by Khurana & Kivelson[1989]

    Parameters
    ----------
    window_size : int, optional
        The size of the window in minutes that is moved over data to average over.
            This should be EVEN to ensure times of MFA and regular data line up.
            The default is 24.

    Returns
    -------
    None.

    """
    # A windows of size 'window_size' in minutes is then moved along the data
    # An average inside of the window is found for each entry
    #print(self.data_df)
    mean_v_data = pd.DataFrame({'MEAN_UX_JSO': [], 'MEAN_UY_JSO': [], 'MEAN_UZ_JSO': []})
    finish_datetime = (v_data_df.index[-1]
    - timedelta(minutes=np.floor(window_size/2)))
    for datetime_index in v_data_df.index:
        start_datetime = datetime_index
        end_datetime = start_datetime + timedelta(minutes=window_size)
        mean_datetime_index = pd.DatetimeIndex([
            (start_datetime + timedelta(minutes=round(window_size/2))).isoformat()
        ])
        
        check_array = v_data_df[start_datetime.isoformat(): end_datetime.isoformat()].dropna()
        
        if len(check_array) < 16:
            
            continue
        
        
        temp_mean_x = np.nanmean(v_data_df[start_datetime.isoformat(): end_datetime.isoformat()].UX_JSO)
        temp_mean_y = np.nanmean(v_data_df[start_datetime.isoformat(): end_datetime.isoformat()].UY_JSO)
        temp_mean_z = np.nanmean(v_data_df[start_datetime.isoformat(): end_datetime.isoformat()].UZ_JSO)

        mean_array_to_concat = pd.DataFrame(
            {'MEAN_UX_JSO': temp_mean_x,
                'MEAN_UY_JSO': temp_mean_y,
                'MEAN_UZ_JSO': temp_mean_z}, index=mean_datetime_index)
        mean_v_data = pd.concat([mean_v_data, mean_array_to_concat])
        
        if mean_datetime_index == finish_datetime:
            break
    # mean_mag_data and data_df are cut to align the time series of each
    # mag_data loses half of the time_window in the front
    # mean_mag_data loses half of the time window in the end
    # The two dataframes are then concatenated into one for simplicity
    #data_df = data_df.drop(data_df[: (data_df.index[0] +
    #     timedelta(minutes=round(window_size / 2) - 1)
    # ).isoformat()].index)
    




    v_data_df = v_data_df[mean_v_data.index[0].isoformat(): 
                                mean_v_data.index[-1].isoformat()]
    v_data_df = pd.concat([v_data_df, mean_v_data], axis=1)
    
    print('v_mean_df made, looking at perts...')
    del mean_v_data
    

    # The perturbation components of the mean field are found.
    # The method used is described in Khurana & Kivelson 1989
    
    
    #mean_mag_vecs = mag_data_df[['MEAN_BX', 'MEAN_BY', 'MEAN_BZ']]
    #mean_mag_magnitude = np.sqrt((mean_mag_vecs**2).sum(axis=1))
    
    mean_mag_x = mag_data_df['MEAN_BX']
    mean_mag_y = mag_data_df['MEAN_BY']
    mean_mag_z = mag_data_df['MEAN_BZ']
    mean_mag_magnitude = np.sqrt(mean_mag_x**2+mean_mag_y**2+mean_mag_z**2)
    mean_mag_vecs = pd.DataFrame({'MEAN_BX': mean_mag_x, 'MEAN_BY': mean_mag_y,'MEAN_BZ': mean_mag_z}, index = mean_mag_x.index)
    
    mean_v_vecs = v_data_df[['MEAN_UX_JSO', 'MEAN_UY_JSO', 'MEAN_UZ_JSO']]
    mean_v_magnitude = np.sqrt((mean_v_vecs**2).sum(axis=1))
    
    mean_ux = v_data_df['MEAN_UX_JSO']
    mean_uy = v_data_df['MEAN_UY_JSO']
    mean_uz = v_data_df['MEAN_UZ_JSO']
    raw_ux = v_data_df['UX_JSO']
    raw_uy = v_data_df['UY_JSO']
    raw_uz = v_data_df['UZ_JSO']
    
    perturbed_ux = raw_ux - mean_ux
    perturbed_uy = raw_uy - mean_uy
    perturbed_uz = raw_uz - mean_uz
    
    perturbed_v_df = pd.DataFrame({'u_x_pert': perturbed_ux, 'u_y_pert': perturbed_uy, 'u_z_pert': perturbed_uz})
    perturbed_v_df_perp = pd.DataFrame({'u_x_pert_perp': [], 'u_y_pert_perp': [], 'u_z_pert_perp': []})
    perturbed_v_df_par = pd.DataFrame({'u_x_pert_par': [], 'u_y_pert_par': [], 'u_z_pert_par': []})
    par_mag_v_df = pd.DataFrame({'u_pert_par': []})
    
    for i in range(len(perturbed_ux)):
        new_df_index = pd.DatetimeIndex([v_data_df.index[i].isoformat()])
        

        
        try: 
            x_for_hat = mean_mag_vecs['MEAN_BX'].loc[new_df_index]
            y_for_hat = mean_mag_vecs['MEAN_BY'].loc[new_df_index]
            z_for_hat = mean_mag_vecs['MEAN_BZ'].loc[new_df_index]

            parallel_mag_hat = (np.asarray([x_for_hat,y_for_hat,z_for_hat]) / mean_mag_magnitude.loc[new_df_index][0])
            print(parallel_mag_hat[0])
            print(parallel_mag_hat[1])
            print(parallel_mag_hat[2])
            print('--------')

            
            perturbed_vparallel_to_mag = np.dot((perturbed_v_df.iloc[i].to_numpy()), parallel_mag_hat)

            print(perturbed_vparallel_to_mag)
            print('------')
            perturbed_vparallel_to_mag_vector = np.asarray(perturbed_vparallel_to_mag*parallel_mag_hat)
            print(perturbed_vparallel_to_mag_vector)
            print('--------')
            perturbed_par_ux = perturbed_vparallel_to_mag_vector[0]
            perturbed_par_uy = perturbed_vparallel_to_mag_vector[1]
            perturbed_par_uz = perturbed_vparallel_to_mag_vector[2]
            perturbed_perp_ux = perturbed_v_df.iloc[i]['u_x_pert'] - perturbed_par_ux
            perturbed_perp_uy = perturbed_v_df.iloc[i]['u_y_pert'] - perturbed_par_uy
            perturbed_perp_uz = perturbed_v_df.iloc[i]['u_z_pert'] - perturbed_par_uz
            print('perturbed_perp_uz=' + str(perturbed_perp_uz) )
            
            
            
            perturbed_v_df_perp = pd.concat([perturbed_v_df_perp,pd.DataFrame({'u_x_pert_perp': perturbed_perp_ux, 'u_y_pert_perp': perturbed_perp_uy, 'u_z_pert_perp': perturbed_perp_uz},
                                    index=new_df_index)])

            perturbed_v_df_par = pd.concat([perturbed_v_df_par, pd.DataFrame({'u_x_pert_par': perturbed_par_ux, 'u_y_pert_par': perturbed_par_uy, 'u_z_pert_par': perturbed_par_uz},
                            index=new_df_index) ])
            
            par_mag_v_df = pd.concat([par_mag_v_df,         pd.DataFrame({'u_pert_par': perturbed_vparallel_to_mag},
                            index=new_df_index)])
        except:
            continue
            
    data_df = pd.concat([v_data_df, perturbed_v_df_perp], axis=1)
    data_df  = pd.concat([data_df, perturbed_v_df_par], axis=1)
    data_df = pd.concat([data_df, par_mag_v_df], axis = 1)
    return data_df

# %%
fits_data = pd.read_csv('/data/juno_spacecraft/data/FWD_FITS/JADE-I_forward_model_ion_v1/JADE-I_forward_model_ion_all_v1.csv', delimiter= ',')
def convert_datetime(datetime_str):
    # Remove the microseconds part
    datetime_str_cleaned = datetime_str.split('.')[0]
    # Convert to pandas datetime object
    date_time = pd.to_datetime(datetime_str_cleaned, format='%Y-%jT%H:%M:%S')
    # Format to the desired output
    return pd.to_datetime(date_time.strftime('%Y-%m-%dT%H:%M:%S'))

fits_data['DATETIME'] = fits_data['                "UTC"'].apply(convert_datetime)
fits_data = fits_data.drop(columns='                "UTC"')

fits_data = fits_data.set_index('DATETIME', drop=True)

ur = fits_data['   "ur"']
uphi = fits_data[' "uphi"']
uz = fits_data['   "uz"']

# %%
startOrbit = 8
endOrbit = 52
save_pickles = True

for i in range(startOrbit, endOrbit+1):
    print('grabbing mean mag orbit ' + str(i))
    filename = '/home/mtfranciscovich/Juno-codes/jss_reduced_inbound_1s_means_4min_pickles/reduced_orbit_' +str(i) +'_4min_means_1s.pkl'
    picklefile = open(filename,'rb')
    orbit_means = pickle.load(picklefile)
    
    orbit_means_columns = list(orbit_means.columns)
    
    
    fits_df_orbit = fits_data[orbit_means.index[0].isoformat(): orbit_means.index[-1].isoformat()]
    
    fits_bad_columns = list(['Tacc', '  "R"', ' "LAT"', 'ELON', ' "LT"',  'dr[MQ16]',
       'dr[O2+]',  'dr[S+]',  'dr[S3+]',
        '     "dn"', '  "u"', ' "du"',  '   "dT"',
       'kappa', 'dkappa', ' "uphi"', 'duphi', '   "ur"', '  "dur"', '   "uz"',
       '  "duz"', 'ISSUES1', 'ISSUES2', 'mode' ])
    
    
    bad_columns = orbit_means_columns + fits_bad_columns
    
    
    combined_df = pd.concat([orbit_means, fits_df_orbit], axis=1)
    
    combined_df = combined_df.drop(columns=bad_columns)
    
    print(combined_df)
    


    
 
    print('Doing delta dens...')
    delta_density_df = delta_densities(combined_df)
    
    if save_pickles:
        delta_density_df.to_pickle('/home/mtfranciscovich/Juno-codes/fits_delta_densities/delta_dens_10min_orbit_' +str(i)+'.pkl')

# %%
#For above to work correctly, ie match up, need to make a df that has all
#of the date times of an orbit, like the og mag mean arrays


startOrbit = 6
endOrbit = 54
save_pickles = False

for i in range(startOrbit, endOrbit+1):
    orbit = i
    print('grabbing orbit ' + str(i))
    filename = '/home/mtfranciscovich/Juno-codes/reduced_inbound_1s_pickles_unit_z_mag/reduced_orbit_' +str(orbit)+'_1s.pkl'
    picklefile = open(filename,'rb')
    rawdata = pickle.load(picklefile)
    
    x = rawdata['X_JSS']
    y = rawdata['Y_JSS']
    z = rawdata['Z_JSS']
    
    Rj_km = 7.14e4
    
    

    phi = np.arctan2(y,x)

    ux = ur*np.cos(phi) - uphi*np.sin(phi)
    uy = ur*np.sin(phi) + uphi*np.cos(phi)

    orbitStartTime = x.index[0]
    orbitEndTime = x.index[-1]

    fits_data_cart_orbit = pd.DataFrame({'UX': ux[orbitStartTime:orbitEndTime], 'UY': uy[orbitStartTime:orbitEndTime], 'UZ': uz[orbitStartTime:orbitEndTime]})
    fits_data_cart_orbit['Z_MAG'] = rawdata['Z_MAG']
    fits_data_cart_orbit['R'] = np.sqrt(rawdata['X_JSS']**2 + rawdata['Y_JSS']**2)/Rj_km
    if save_pickles:
        fits_data_cart_orbit.to_pickle('/home/mtfranciscovich/Juno-codes/fits_u_cart_pickles_updated/u_cart_orbit_' +str(i)+'.pkl')

# %%
#For above to work correctly, ie match up, need to make a df that has all
#of the date times of an orbit, like the og mag mean arrays


startOrbit = 6
endOrbit = 6
save_pickles = True

for i in range(startOrbit, endOrbit+1):
    orbit = i
    print('grabbing orbit ' + str(i))
    filename = '/home/mtfranciscovich/Juno-codes/mean_mag_data_4min/jss_reduced_inbound_1s_means_4min_pickles/reduced_orbit_' +str(i) +'_4min_means_1s.pkl'
    picklefile = open(filename,'rb')
    mean_mag_data = pickle.load(picklefile)

    filename = '/home/mtfranciscovich/Juno-codes/jso_velos/orbit_' +str(i) +'.pkl'
    picklefile = open(filename,'rb')
    v_df = pickle.load(picklefile)

    mean_v_df = mean_field_align_v_new(mean_mag_data, v_df,window_size=10)


    

    if save_pickles:
        mean_v_df.to_pickle('/home/mtfranciscovich/Juno-codes/jso_mean_velos_16dp_10min/orbit_' +str(i)+'.pkl')
# Out:
# grabbing orbit 6
# v_mean_df made, looking at perts...
# [-0.5657909]
# [-0.82121187]
# [-0.07410611]
# --------
# [-15.87602207]
# ------
# [[ 8.98250879]
#  [13.03757785]
#  [ 1.1765103 ]]
# --------
# perturbed_perp_uz=[-7.47229729]
# [-0.58793128]
# [-0.80435493]
# [-0.08573191]
# --------
# [-24.53487621]
# ------
# [[14.42482115]
#  [19.73474859]
#  [ 2.10342178]]
# --------
# perturbed_perp_uz=[25.81805538]
# [-0.6029596]
# [-0.78907226]
# [-0.11749336]
# --------
# [-11.61274744]
# ------
# [[7.00201754]
#  [9.16329687]
#  [1.36442069]]
# --------
# perturbed_perp_uz=[2.64167404]
# [-0.59406346]
# [-0.79026581]
# [-0.15022838]
# --------
# [-16.66922834]
# ------
# [[ 9.90257938]
#  [13.17312118]
#  [ 2.50419116]]
# --------
# perturbed_perp_uz=[-4.61173682]
# [-0.58049817]
# [-0.7908527]
# [-0.19383984]
# --------
# [-39.58469761]
# ------
# [[22.97884457]
#  [31.3056649 ]
#  [ 7.67309145]]
# --------
# perturbed_perp_uz=[35.70612595]
# [-0.58633683]
# [-0.77615766]
# [-0.23192329]
# --------
# [-30.55561739]
# ------
# [[17.91588374]
#  [23.71597649]
#  [ 7.08655932]]
# --------
# perturbed_perp_uz=[12.28129647]
# [-0.61542362]
# [-0.73785978]
# [-0.2771583]
# --------
# [-0.6982144]
# ------
# [[0.42969763]
#  [0.51518432]
#  [0.19351591]]
# --------
# perturbed_perp_uz=[-8.17775427]
# [-0.62669272]
# [-0.71183035]
# [-0.31710217]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.62855371]
# [-0.69356243]
# [-0.35198208]
# --------
# [-16.5276546]
# ------
# [[10.38851867]
#  [11.46296025]
#  [ 5.81743832]]
# --------
# perturbed_perp_uz=[4.35217454]
# [-0.61873037]
# [-0.68897149]
# [-0.37747982]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.61350645]
# [-0.69326878]
# [-0.37813786]
# --------
# [-24.05310693]
# ------
# [[14.75673617]
#  [16.675268  ]
#  [ 9.09539046]]
# --------
# perturbed_perp_uz=[6.79674104]
# [-0.62321015]
# [-0.68770973]
# [-0.37237675]
# --------
# [-11.48921477]
# ------
# [[7.16019523]
#  [7.90124474]
#  [4.27831647]]
# --------
# perturbed_perp_uz=[-5.30465386]
# [-0.6305578]
# [-0.68995069]
# [-0.35547842]
# --------
# [8.53736231]
# ------
# [[-5.3833004 ]
#  [-5.89035902]
#  [-3.03484803]]
# --------
# perturbed_perp_uz=[-28.77414803]
# [-0.60186634]
# [-0.71725622]
# [-0.35114161]
# --------
# [-26.43995239]
# ------
# [[15.91331741]
#  [18.96422021]
#  [ 9.28416732]]
# --------
# perturbed_perp_uz=[7.12476058]
# [-0.4621983]
# [-0.84045314]
# [-0.2828626]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.49179179]
# [-0.83345915]
# [-0.25196565]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.54078078]
# [-0.81310327]
# [-0.21545119]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.5570552]
# [-0.80024546]
# [-0.22202862]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.58898769]
# [-0.77725402]
# [-0.22129096]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.62714411]
# [-0.73472506]
# [-0.25859109]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.68533248]
# [-0.67781506]
# [-0.2662445]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.74363209]
# [-0.5997948]
# [-0.29539384]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.7273144]
# [-0.59079455]
# [-0.34925]
# --------
# [40.27250845]
# ------
# [[-29.29077527]
#  [-23.79277849]
#  [-14.06517377]]
# --------
# perturbed_perp_uz=[-17.89062304]
# [-0.75472776]
# [-0.56647332]
# [-0.33089877]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.77902963]
# [-0.53666397]
# [-0.32419843]
# --------
# [-18.60722529]
# ------
# [[14.49557986]
#  [ 9.98582734]
#  [ 6.03243317]]
# --------
# perturbed_perp_uz=[-17.34698088]
# [-0.80225194]
# [-0.52795988]
# [-0.27865784]
# --------
# [55.96320209]
# ------
# [[-44.89658749]
#  [-29.54632523]
#  [-15.59458512]]
# --------
# perturbed_perp_uz=[-9.59459597]
# [-0.81518833]
# [-0.52040332]
# [-0.25426046]
# --------
# [12.83312401]
# ------
# [[-10.46141288]
#  [ -6.6784003 ]
#  [ -3.26295599]]
# --------
# perturbed_perp_uz=[50.56563425]
# [-0.83445458]
# [-0.50264518]
# [-0.2259057]
# --------
# [-5.01475827]
# ------
# [[4.18458799]
#  [2.52064406]
#  [1.13286248]]
# --------
# perturbed_perp_uz=[-19.91617794]
# [-0.85436261]
# [-0.47886832]
# [-0.20186548]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.87070902]
# [-0.46113482]
# [-0.17093997]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.87776689]
# [-0.44821333]
# [-0.16920429]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.86732476]
# [-0.44190458]
# [-0.22905916]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.86473629]
# [-0.4286678]
# [-0.2616774]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.78175318]
# [-0.33390527]
# [-0.52665856]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.75969809]
# [-0.26131514]
# [-0.59546051]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.53018935]
# [-0.10605945]
# [-0.84121974]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.25587848]
# [0.17998784]
# [-0.94980555]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.01930817]
# [0.71703679]
# [-0.69676785]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.50197234]
# [0.86014218]
# [-0.09043891]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.54513294]
# [0.8351119]
# [-0.0736084]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.57877511]
# [0.81247696]
# [-0.07000406]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.61304162]
# [0.7865586]
# [-0.07419941]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.63533026]
# [0.76774752]
# [-0.08318179]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.64165943]
# [0.76089378]
# [-0.0965082]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.65204974]
# [0.74903668]
# [-0.11736778]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.63479394]
# [0.76235034]
# [-0.125931]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.60579826]
# [0.78444277]
# [-0.13288344]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.61500881]
# [0.77907527]
# [-0.12167941]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.622549]
# [0.77425433]
# [-0.11385507]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.63388408]
# [0.76553673]
# [-0.11020202]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.69062916]
# [0.71261525]
# [-0.12333236]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.66282022]
# [0.73600201]
# [-0.13773305]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.64470602]
# [0.75259342]
# [-0.13400484]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.60576631]
# [0.79200549]
# [-0.07599008]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.64048861]
# [0.76066462]
# [-0.10565828]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.65352559]
# [0.74785854]
# [-0.11667007]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.65526419]
# [0.74573564]
# [-0.12044581]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.65569111]
# [0.74483293]
# [-0.12366518]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.60180456]
# [0.78312994]
# [-0.15664855]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.59895047]
# [0.78515706]
# [-0.15743802]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.59806791]
# [0.78746707]
# [-0.14903149]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.60246081]
# [0.7849449]
# [-0.14457688]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.6017043]
# [0.78585699]
# [-0.1427611]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.5998491]
# [0.78743582]
# [-0.14186574]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.60487178]
# [0.78362256]
# [-0.14165387]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.60718469]
# [0.78116604]
# [-0.14528032]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.60589099]
# [0.78199439]
# [-0.146222]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.60293962]
# [0.78409996]
# [-0.14714299]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.60622855]
# [0.78140511]
# [-0.14796286]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.60677459]
# [0.78129232]
# [-0.14631096]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.61210796]
# [0.77761211]
# [-0.14367761]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.61801781]
# [0.77303311]
# [-0.14308666]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.6316501]
# [0.76170052]
# [-0.14432766]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.63048689]
# [0.761301]
# [-0.15135084]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.63520664]
# [0.75736959]
# [-0.15134011]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.64484926]
# [0.74985351]
# [-0.14794978]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.6556319]
# [0.74062385]
# [-0.14704801]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.68743196]
# [0.7135068]
# [-0.13544503]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.67299836]
# [0.72547818]
# [-0.14406468]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.65318209]
# [0.74126049]
# [-0.15455109]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.64170445]
# [0.75047158]
# [-0.15813857]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.63488374]
# [0.75529361]
# [-0.1626475]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.62848632]
# [0.7598653]
# [-0.16616158]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.6162512]
# [0.76899295]
# [-0.16995383]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.63204743]
# [0.75675432]
# [-0.16685006]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.63552606]
# [0.75486148]
# [-0.16214429]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.63485932]
# [0.75672442]
# [-0.15595447]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.64112764]
# [0.75810967]
# [-0.11926892]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.60400667]
# [0.77946305]
# [-0.16617249]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.59134617]
# [0.78679825]
# [-0.17679996]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.5907349]
# [0.78646012]
# [-0.18031291]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.59472865]
# [0.78370402]
# [-0.17918104]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.59533434]
# [0.78290512]
# [-0.18065604]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.60116734]
# [0.77948376]
# [-0.17607639]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.60712385]
# [0.77577563]
# [-0.17196744]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.62012983]
# [0.7667164]
# [-0.16608721]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.62644117]
# [0.76207297]
# [-0.16375668]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.64172642]
# [0.75112531]
# [-0.1549128]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.64799202]
# [0.74577032]
# [-0.15470283]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.64278299]
# [0.74707644]
# [-0.16943086]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.63590193]
# [0.75191428]
# [-0.17393577]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.63009718]
# [0.75646497]
# [-0.17532338]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.62258435]
# [0.76200345]
# [-0.17815574]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.61671032]
# [0.76677688]
# [-0.1781056]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.6181295]
# [0.76690648]
# [-0.17254094]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.62518308]
# [0.76617661]
# [-0.14872634]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.62708069]
# [0.7649181]
# [-0.14720769]
# --------
# [5.60492024]
# ------
# [[ 3.51473728]
#  [ 4.28730494]
#  [-0.82508737]]
# --------
# perturbed_perp_uz=[16.84614244]
# [0.63404717]
# [0.75989567]
# [-0.14332745]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.64635368]
# [0.75007007]
# [-0.14007787]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.65397951]
# [0.74426998]
# [-0.13554701]
# --------
# [11.67043017]
# ------
# [[ 7.63222225]
#  [ 8.68595083]
#  [-1.58189192]]
# --------
# perturbed_perp_uz=[-8.85106718]
# [0.65905128]
# [0.74066935]
# [-0.13061516]
# --------
# [11.89002004]
# ------
# [[ 7.83613292]
#  [ 8.80657345]
#  [-1.55301693]]
# --------
# perturbed_perp_uz=[-23.94416239]
# [0.66016429]
# [0.74035626]
# [-0.12671115]
# --------
# [12.8940105]
# ------
# [[ 8.51216526]
#  [ 9.54616144]
#  [-1.63381487]]
# --------
# perturbed_perp_uz=[30.18804489]
# [0.65951328]
# [0.74179893]
# [-0.12155892]
# --------
# [-9.05176827]
# ------
# [[-5.96976141]
#  [-6.71459205]
#  [ 1.1003232 ]]
# --------
# perturbed_perp_uz=[-64.97141967]
# [0.65685316]
# [0.74621436]
# [-0.10820375]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.64509835]
# [0.75654637]
# [-0.10717138]
# --------
# [-1.10066818]
# ------
# [[-0.71003923]
#  [-0.83270652]
#  [ 0.11796013]]
# --------
# perturbed_perp_uz=[18.75665481]
# [0.63011521]
# [0.76939462]
# [-0.10481766]
# --------
# [-0.42830444]
# ------
# [[-0.26988114]
#  [-0.32953513]
#  [ 0.04489387]]
# --------
# perturbed_perp_uz=[-33.82203728]
# [0.61847502]
# [0.77851682]
# [-0.10677173]
# --------
# [-18.28259582]
# ------
# [[-11.30732883]
#  [-14.23330844]
#  [  1.95206443]]
# --------
# perturbed_perp_uz=[31.86087445]
# [0.60782074]
# [0.78691319]
# [-0.10640292]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.60396412]
# [0.79064801]
# [-0.10051402]
# --------
# [-20.96499426]
# ------
# [[-12.66210438]
#  [-16.57593089]
#  [  2.10727593]]
# --------
# perturbed_perp_uz=[-47.67608405]
# [0.6071531]
# [0.78912692]
# [-0.09297211]
# --------
# [11.17261771]
# ------
# [[ 6.7834895 ]
#  [ 8.81661341]
#  [-1.03874186]]
# --------
# perturbed_perp_uz=[64.42287346]
# [0.61469513]
# [0.78417556]
# [-0.08496228]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.62446466]
# [0.77757878]
# [-0.07358754]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.63657347]
# [0.76889458]
# [-0.05979421]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.63965009]
# [0.76657117]
# [-0.05671336]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.64772459]
# [0.75996842]
# [-0.05385963]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.65404548]
# [0.75430846]
# [-0.05694951]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.67798204]
# [0.73175203]
# [-0.06985215]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.6889415]
# [0.72153743]
# [-0.06887197]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.72529907]
# [0.6833326]
# [-0.083653]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.74175586]
# [0.66595729]
# [-0.07936705]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.75806589]
# [0.64760603]
# [-0.07708783]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.77526638]
# [0.6275934]
# [-0.07133421]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.78905841]
# [0.60726351]
# [-0.09283241]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.72583802]
# [0.61835692]
# [-0.30132024]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.7392632]
# [0.59330318]
# [-0.31856122]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.71841483]
# [0.55317309]
# [-0.42175782]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.5751077]
# [0.60626715]
# [-0.5492643]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.60210374]
# [0.62336497]
# [-0.49888596]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.66295385]
# [0.58475916]
# [-0.46749215]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.2294154]
# [-0.74054536]
# [-0.63163371]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.1000664]
# [-0.9651588]
# [-0.24177512]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.36968018]
# [-0.92166621]
# [-0.1177623]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.46538952]
# [-0.88336611]
# [-0.05546984]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.50389136]
# [-0.86311065]
# [0.03366756]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.53419533]
# [-0.8451491]
# [0.01892984]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.56517866]
# [-0.82483884]
# [-0.01462777]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.54179082]
# [-0.8397957]
# [-0.0347261]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.52751028]
# [-0.84865912]
# [-0.0388664]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.48432565]
# [-0.87424102]
# [-0.03363501]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.47351149]
# [-0.87985737]
# [-0.04047069]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.46596997]
# [-0.88364072]
# [-0.04528866]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.46438947]
# [-0.88417284]
# [-0.05080175]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.47099691]
# [-0.88148359]
# [-0.03389096]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.48739818]
# [-0.87280403]
# [-0.02561523]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.50397739]
# [-0.86347653]
# [-0.02037321]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.51183465]
# [-0.85888369]
# [-0.01854976]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.51995779]
# [-0.85396278]
# [-0.01978566]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.50518116]
# [-0.86290343]
# [0.01377222]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.514167]
# [-0.85749738]
# [0.01818061]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.63959135]
# [-0.76115107]
# [-0.10757298]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.64508132]
# [-0.7557134]
# [-0.11299266]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.60808867]
# [-0.7722302]
# [-0.1840888]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.62269518]
# [-0.75882294]
# [-0.1908886]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.64138395]
# [-0.74408711]
# [-0.18697861]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.66030504]
# [-0.72974456]
# [-0.17739821]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.6504277]
# [-0.73364451]
# [-0.19674739]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.62656253]
# [-0.73578424]
# [-0.25698432]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.61228134]
# [-0.73476942]
# [-0.29193401]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.60254233]
# [-0.72634435]
# [-0.33070625]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.58273268]
# [-0.72122396]
# [-0.37451118]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.55284018]
# [-0.72045315]
# [-0.41870633]
# --------
# [4.06478508]
# ------
# [[-2.24717653]
#  [-2.92848722]
#  [-1.70195123]]
# --------
# perturbed_perp_uz=[-10.81974161]
# [-0.51336984]
# [-0.72634323]
# [-0.45703054]
# --------
# [-29.77451549]
# ------
# [[15.28533831]
#  [21.62651786]
#  [13.60786283]]
# --------
# perturbed_perp_uz=[23.04979659]
# [-0.53271144]
# [-0.72118669]
# [-0.44284114]
# --------
# [-23.58877251]
# ------
# [[12.56600894]
#  [17.01190887]
#  [10.4460789 ]]
# --------
# perturbed_perp_uz=[19.64773496]
# [-0.53439092]
# [-0.7422608]
# [-0.40432073]
# --------
# [-27.35101233]
# ------
# [[14.61613273]
#  [20.30158423]
#  [11.05858114]]
# --------
# perturbed_perp_uz=[15.47996466]
# [-0.54296507]
# [-0.76062305]
# [-0.35586726]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.54617575]
# [-0.77184217]
# [-0.32550225]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.53786798]
# [-0.78262067]
# [-0.31337344]
# --------
# [6.9091537]
# ------
# [[-3.71621257]
#  [-5.40724651]
#  [-2.16514529]]
# --------
# perturbed_perp_uz=[-13.74238501]
# [-0.53136856]
# [-0.78898066]
# [-0.30847523]
# --------
# [24.65905316]
# ------
# [[-13.10304548]
#  [-19.45551615]
#  [ -7.60670715]]
# --------
# perturbed_perp_uz=[-53.03302052]
# [-0.5222539]
# [-0.79085616]
# [-0.31905703]
# --------
# [-0.00543628]
# ------
# [[0.00283912]
#  [0.00429932]
#  [0.00173448]]
# --------
# perturbed_perp_uz=[1.62572388]
# [-0.52666395]
# [-0.78856331]
# [-0.31747912]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.52978124]
# [-0.78538536]
# [-0.32015881]
# --------
# [29.20326437]
# ------
# [[-15.47134166]
#  [-22.93581641]
#  [ -9.34968248]]
# --------
# perturbed_perp_uz=[-29.43261421]
# [-0.52739313]
# [-0.76793066]
# [-0.36350928]
# --------
# [17.55794722]
# ------
# [[ -9.25994071]
#  [-13.48328593]
#  [ -6.38247672]]
# --------
# perturbed_perp_uz=[28.57983479]
# [-0.52218497]
# [-0.74481604]
# [-0.41541777]
# --------
# [11.49150865]
# ------
# [[-6.00069311]
#  [-8.55905999]
#  [-4.77377685]]
# --------
# perturbed_perp_uz=[2.06917256]
# [-0.49197235]
# [-0.72755987]
# [-0.47814208]
# --------
# [20.14710219]
# ------
# [[ -9.91181719]
#  [-14.658223  ]
#  [ -9.63317732]]
# --------
# perturbed_perp_uz=[-12.26683894]
# [-0.44692389]
# [-0.70466891]
# [-0.55109052]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.37687297]
# [-0.68362007]
# [-0.6250043]
# --------
# [11.10946041]
# ------
# [[-4.18685534]
#  [-7.59465005]
#  [-6.94346049]]
# --------
# perturbed_perp_uz=[-20.52140027]
# [-0.31855184]
# [-0.64498193]
# [-0.69463878]
# --------
# [2.84079109]
# ------
# [[-0.90493923]
#  [-1.83225893]
#  [-1.97332365]]
# --------
# perturbed_perp_uz=[-10.93957452]
# [-0.2249326]
# [-0.58880584]
# [-0.77634593]
# --------
# [-5.67083803]
# ------
# [[1.27555636]
#  [3.33902257]
#  [4.40253202]]
# --------
# perturbed_perp_uz=[4.23265867]
# [-0.16106727]
# [-0.55202391]
# [-0.81812404]
# --------
# [24.78686777]
# ------
# [[ -3.992353  ]
#  [-13.6829437 ]
#  [-20.27873229]]
# --------
# perturbed_perp_uz=[-2.00072838]
# [-0.06499588]
# [-0.52131451]
# [-0.85088584]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.01896925]
# [-0.44932226]
# [-0.89316833]
# --------
# [5.38323158]
# ------
# [[ 0.10211586]
#  [-2.41880579]
#  [-4.80813198]]
# --------
# perturbed_perp_uz=[1.54571967]
# [0.11143249]
# [-0.30746916]
# [-0.94501085]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.17360877]
# [-0.1938845]
# [-0.96554067]
# --------
# [-32.62186785]
# ------
# [[-5.66344249]
#  [ 6.32487469]
#  [31.49774025]]
# --------
# perturbed_perp_uz=[8.04012997]
# [0.1706607]
# [-0.11234911]
# [-0.97890378]
# --------
# [0.40518162]
# ------
# [[ 0.06914858]
#  [-0.04552179]
#  [-0.39663381]]
# --------
# perturbed_perp_uz=[3.36700378]
# [0.1519741]
# [-0.05524643]
# [-0.98683925]
# --------
# [30.37489813]
# ------
# [[  4.61619784]
#  [ -1.67810481]
#  [-29.97514167]]
# --------
# perturbed_perp_uz=[2.1673609]
# [0.13300379]
# [0.00304917]
# [-0.99111084]
# --------
# [-39.83858731]
# ------
# [[-5.29868313]
#  [-0.12147466]
#  [39.48445568]]
# --------
# perturbed_perp_uz=[1.76461082]
# [0.13177017]
# [0.09237246]
# [-0.98696705]
# --------
# [-8.56856984]
# ------
# [[-1.12908189]
#  [-0.79149991]
#  [ 8.45689607]]
# --------
# perturbed_perp_uz=[1.25947358]
# [0.13492838]
# [0.1944546]
# [-0.97158723]
# --------
# [31.68291111]
# ------
# [[  4.27492397]
#  [  6.16088789]
#  [-30.78271173]]
# --------
# perturbed_perp_uz=[0.1742969]
# [0.19300615]
# [0.28347512]
# [-0.93935642]
# --------
# [-24.09543316]
# ------
# [[-4.65056686]
#  [-6.83045575]
#  [22.63419982]]
# --------
# perturbed_perp_uz=[4.6547646]
# [0.28357833]
# [0.36107844]
# [-0.88837249]
# --------
# [17.88283452]
# ------
# [[  5.07118443]
#  [  6.45710595]
#  [-15.88661832]]
# --------
# perturbed_perp_uz=[3.16372888]
# [0.36450479]
# [0.45667149]
# [-0.81153399]
# --------
# [13.78086653]
# ------
# [[  5.02319184]
#  [  6.29332879]
#  [-11.18364157]]
# --------
# perturbed_perp_uz=[-12.04242484]
# [0.43248864]
# [0.55716981]
# [-0.70888319]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.49558016]
# [0.62457397]
# [-0.60357904]
# --------
# [8.43537479]
# ------
# [[ 4.18040439]
#  [ 5.2685155 ]
#  [-5.09141545]]
# --------
# perturbed_perp_uz=[5.32371934]
# [0.54420951]
# [0.66077823]
# [-0.5169218]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.58675492]
# [0.67220452]
# [-0.45150829]
# --------
# [-0.40283876]
# ------
# [[-0.23636762]
#  [-0.27079004]
#  [ 0.18188504]]
# --------
# perturbed_perp_uz=[32.16887518]
# [0.61997788]
# [0.68484347]
# [-0.38290579]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.63808721]
# [0.70267195]
# [-0.31479651]
# --------
# [17.49130695]
# ------
# [[11.16097931]
#  [12.29065073]
#  [-5.50620236]]
# --------
# perturbed_perp_uz=[-21.18606993]
# [0.65186603]
# [0.7080629]
# [-0.27150985]
# --------
# [5.86408215]
# ------
# [[ 3.82259597]
#  [ 4.15213903]
#  [-1.59215608]]
# --------
# perturbed_perp_uz=[28.77677867]
# [0.6674897]
# [0.70282914]
# [-0.24594451]
# --------
# [5.98516605]
# ------
# [[ 3.99503667]
#  [ 4.20654912]
#  [-1.47201873]]
# --------
# perturbed_perp_uz=[-4.43889134]
# [0.68563726]
# [0.68849567]
# [-0.23637948]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.70679872]
# [0.6697902]
# [-0.22763272]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.71237431]
# [0.66508493]
# [-0.22401982]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.71540369]
# [0.65564802]
# [-0.24150203]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.70691574]
# [0.66374685]
# [-0.24435684]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.69576488]
# [0.67530222]
# [-0.24470012]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.68595732]
# [0.68584832]
# [-0.24305274]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.68122516]
# [0.69231427]
# [-0.23797736]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.68853659]
# [0.68638993]
# [-0.23406458]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.68864175]
# [0.69024173]
# [-0.22212362]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.68303275]
# [0.70269445]
# [-0.1992154]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.67985843]
# [0.71203026]
# [-0.17551475]
# --------
# [13.40995835]
# ------
# [[ 9.11687326]
#  [ 9.54829607]
#  [-2.35364548]]
# --------
# perturbed_perp_uz=[-26.60967799]
# [0.68391453]
# [0.71303809]
# [-0.15439431]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.69149533]
# [0.70837047]
# [-0.14158207]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.69498964]
# [0.70654792]
# [-0.13333959]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.69524811]
# [0.70726256]
# [-0.12810046]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.69275178]
# [0.71012792]
# [-0.12575097]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.69534918]
# [0.7071464]
# [-0.12819315]
# --------
# [-9.28847653]
# ------
# [[-6.45873452]
#  [-6.56831277]
#  [ 1.19071904]]
# --------
# perturbed_perp_uz=[-14.37806736]
# [0.70834239]
# [0.6915709]
# [-0.14135327]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.72484087]
# [0.66915606]
# [-0.16381661]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.73243866]
# [0.65509862]
# [-0.18541682]
# --------
# [11.29491192]
# ------
# [[ 8.27283021]
#  [ 7.39928125]
#  [-2.09426664]]
# --------
# perturbed_perp_uz=[-13.29333068]
# [0.73232672]
# [0.65176163]
# [-0.19724188]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.7336927]
# [0.648718]
# [-0.20213852]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.73322322]
# [0.64844207]
# [-0.204711]
# --------
# [43.40324539]
# ------
# [[31.82426737]
#  [28.14449014]
#  [-8.88512191]]
# --------
# perturbed_perp_uz=[38.45823797]
# [0.73312466]
# [0.64857727]
# [-0.20463566]
# --------
# [-17.87833885]
# ------
# [[-13.10705113]
#  [-11.59548422]
#  [  3.65854566]]
# --------
# perturbed_perp_uz=[13.38850237]
# [0.73417199]
# [0.64687934]
# [-0.20624891]
# --------
# [7.93289477]
# ------
# [[ 5.82410915]
#  [ 5.13162571]
#  [-1.63615088]]
# --------
# perturbed_perp_uz=[4.82960194]
# [0.731202]
# [0.64945064]
# [-0.20870434]
# --------
# [13.69185121]
# ------
# [[10.01150902]
#  [ 8.89218151]
#  [-2.85754873]]
# --------
# perturbed_perp_uz=[-62.28349945]
# [0.72421578]
# [0.65810233]
# [-0.20594373]
# --------
# [-57.07875419]
# ------
# [[-41.33733463]
#  [-37.56366135]
#  [ 11.75501136]]
# --------
# perturbed_perp_uz=[13.4903952]
# [0.71562469]
# [0.66872444]
# [-0.20171494]
# --------
# [-15.88087475]
# ------
# [[-11.36474611]
#  [-10.61992912]
#  [  3.20340978]]
# --------
# perturbed_perp_uz=[-26.48920963]
# [0.70780756]
# [0.67722554]
# [-0.20093289]
# --------
# [11.87203417]
# ------
# [[ 8.40311559]
#  [ 8.04004472]
#  [-2.38548208]]
# --------
# perturbed_perp_uz=[-51.22829563]
# [0.69997341]
# [0.68414097]
# [-0.20491061]
# --------
# [14.9014774]
# ------
# [[10.43063793]
#  [10.19471123]
#  [-3.05347086]]
# --------
# perturbed_perp_uz=[-6.3895596]
# [0.68144972]
# [0.69904619]
# [-0.21670419]
# --------
# [-32.21463484]
# ------
# [[-21.95265394]
#  [-22.51951762]
#  [  6.98104641]]
# --------
# perturbed_perp_uz=[10.11769137]
# [0.67639967]
# [0.70221988]
# [-0.22219525]
# --------
# [31.54979713]
# ------
# [[21.3402725 ]
#  [22.15489461]
#  [-7.01021492]]
# --------
# perturbed_perp_uz=[17.83799961]
# [0.67016608]
# [0.70679251]
# [-0.22654309]
# --------
# [9.78801693]
# ------
# [[ 6.55959696]
#  [ 6.91809704]
#  [-2.2174076 ]]
# --------
# perturbed_perp_uz=[-8.39719067]
# [0.66623082]
# [0.70879185]
# [-0.23184177]
# --------
# [1.96207609]
# ------
# [[ 1.30719556]
#  [ 1.39070355]
#  [-0.4548912 ]]
# --------
# perturbed_perp_uz=[25.8057372]
# [0.66672256]
# [0.70703246]
# [-0.23576712]
# --------
# [-1.6406055]
# ------
# [[-1.0938287 ]
#  [-1.15996134]
#  [ 0.38680083]]
# --------
# perturbed_perp_uz=[6.72340737]
# [0.66530362]
# [0.70694332]
# [-0.24000465]
# --------
# [-29.7287394]
# ------
# [[-19.77863806]
#  [-21.01653372]
#  [  7.13503563]]
# --------
# perturbed_perp_uz=[-37.91309747]
# [0.66335055]
# [0.70745653]
# [-0.24386737]
# --------
# [-40.54683405]
# ------
# [[-26.89676481]
#  [-28.68512271]
#  [  9.88804983]]
# --------
# perturbed_perp_uz=[8.12170997]
# [0.65831086]
# [0.71027103]
# [-0.2492827]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.65227662]
# [0.71462729]
# [-0.25267179]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.64176812]
# [0.72424615]
# [-0.25219278]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.63306232]
# [0.73355414]
# [-0.24724567]
# --------
# [12.69175779]
# ------
# [[ 8.03467365]
#  [ 9.31009147]
#  [-3.13798215]]
# --------
# perturbed_perp_uz=[-4.52266882]
# [0.62397174]
# [0.74327489]
# [-0.24125031]
# --------
# [16.66561273]
# ------
# [[10.39887129]
#  [12.38713146]
#  [-4.02058425]]
# --------
# perturbed_perp_uz=[17.65936541]
# [0.60962293]
# [0.75739937]
# [-0.2338933]
# --------
# [-8.26287021]
# ------
# [[-5.03723517]
#  [-6.25829269]
#  [ 1.93262999]]
# --------
# perturbed_perp_uz=[15.72609396]
# [0.60181254]
# [0.76522192]
# [-0.2285981]
# --------
# [17.12853556]
# ------
# [[10.30816746]
#  [13.10713078]
#  [-3.91555063]]
# --------
# perturbed_perp_uz=[-19.41641159]
# [0.59767317]
# [0.77034786]
# [-0.22215075]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.59792132]
# [0.7721691]
# [-0.21504645]
# --------
# [-7.11243727]
# ------
# [[-4.25267789]
#  [-5.49200428]
#  [ 1.52950439]]
# --------
# perturbed_perp_uz=[-2.68519861]
# [0.5948519]
# [0.77700055]
# [-0.20596449]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.59436153]
# [0.77956907]
# [-0.19750048]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.59071751]
# [0.78488534]
# [-0.18710378]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.59091805]
# [0.78647606]
# [-0.17964202]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.59251278]
# [0.7869523]
# [-0.1721473]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.58351162]
# [0.79795423]
# [-0.15094118]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.5782387]
# [0.80475297]
# [-0.13421125]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.59475825]
# [0.7952175]
# [-0.11786325]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.61761438]
# [0.77832821]
# [-0.11294989]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.62953184]
# [0.7685566]
# [-0.11406322]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.63987217]
# [0.75931987]
# [-0.11830868]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.65446628]
# [0.73135759]
# [-0.19180711]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.65595662]
# [0.72786212]
# [-0.19984407]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.64300315]
# [0.73776931]
# [-0.20553198]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.68766505]
# [0.70583934]
# [-0.17002234]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.64185372]
# [0.74390754]
# [-0.18607896]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.58304813]
# [0.7833646]
# [-0.2153945]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.57871234]
# [0.78677586]
# [-0.21465269]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.58766374]
# [0.78014129]
# [-0.21454812]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.59664248]
# [0.77352066]
# [-0.21373709]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.60463166]
# [0.76738183]
# [-0.21341433]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.61789412]
# [0.75827869]
# [-0.20789489]
# --------
# [-2.54589964]
# ------
# [[-1.57309642]
#  [-1.93050144]
#  [ 0.52927953]]
# --------
# perturbed_perp_uz=[-3.8840685]
# [0.63454718]
# [0.74617521]
# [-0.20142601]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.64420715]
# [0.73917376]
# [-0.19651793]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.64566707]
# [0.73810742]
# [-0.19573315]
# --------
# [10.64448204]
# ------
# [[ 6.87279155]
#  [ 7.85677119]
#  [-2.083478  ]]
# --------
# perturbed_perp_uz=[51.71687597]
# [0.64723737]
# [0.73698166]
# [-0.19478661]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.65606817]
# [0.73050188]
# [-0.1895826]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.66529655]
# [0.72268628]
# [-0.18736338]
# --------
# [-23.53633071]
# ------
# [[-15.65863968]
#  [-17.00938331]
#  [  4.40984649]]
# --------
# perturbed_perp_uz=[31.53792193]
# [0.6677336]
# [0.71996039]
# [-0.18917946]
# --------
# [-16.34872269]
# ------
# [[-10.91659153]
#  [-11.77043279]
#  [  3.09284254]]
# --------
# perturbed_perp_uz=[15.52996668]
# [0.66808594]
# [0.71937203]
# [-0.19017112]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.66940802]
# [0.7184336]
# [-0.18906629]
# --------
# [-17.10029823]
# ------
# [[-11.44707678]
#  [-12.28542887]
#  [  3.23308988]]
# --------
# perturbed_perp_uz=[11.84176976]
# [0.67241286]
# [0.7149543]
# [-0.19157581]
# --------
# [1.19491477]
# ------
# [[ 0.80347606]
#  [ 0.85430945]
#  [-0.22891676]]
# --------
# perturbed_perp_uz=[-20.26773399]
# [0.67977725]
# [0.707638]
# [-0.19274685]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.68287477]
# [0.70377994]
# [-0.19589755]
# --------
# [15.16215075]
# ------
# [[10.35385022]
#  [10.67081748]
#  [-2.97022813]]
# --------
# perturbed_perp_uz=[12.59556339]
# [0.67599835]
# [0.70814184]
# [-0.20386605]
# --------
# [3.61436343]
# ------
# [[ 2.44330371]
#  [ 2.55948197]
#  [-0.73684599]]
# --------
# perturbed_perp_uz=[-22.03355928]
# [0.67321562]
# [0.71026023]
# [-0.2056967]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.67049153]
# [0.71221062]
# [-0.2078392]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.66536705]
# [0.71528228]
# [-0.21367721]
# --------
# [24.06060687]
# ------
# [[16.00913498]
#  [17.21012577]
#  [-5.14120328]]
# --------
# perturbed_perp_uz=[-38.41524466]
# [0.66089324]
# [0.71745915]
# [-0.22016471]
# --------
# [-21.74532346]
# ------
# [[-14.37133721]
#  [-15.60138127]
#  [  4.78755279]]
# --------
# perturbed_perp_uz=[38.47318366]
# [0.65567914]
# [0.72096054]
# [-0.22427832]
# --------
# [-15.80261798]
# ------
# [[-10.36144693]
#  [-11.39306404]
#  [  3.5441846 ]]
# --------
# perturbed_perp_uz=[-1.27417846]
# [0.64976639]
# [0.72398627]
# [-0.23161936]
# --------
# [33.67970567]
# ------
# [[21.88394061]
#  [24.38364446]
#  [-7.80087174]]
# --------
# perturbed_perp_uz=[-41.10015425]
# [0.64306223]
# [0.72679357]
# [-0.24133395]
# --------
# [-4.85576683]
# ------
# [[-3.12256025]
#  [-3.52914011]
#  [ 1.17186141]]
# --------
# perturbed_perp_uz=[22.06639858]
# [0.64141318]
# [0.72719388]
# [-0.24449579]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.63415846]
# [0.73365783]
# [-0.24410908]
# --------
# [-0.8046379]
# ------
# [[-0.51026792]
#  [-0.59032889]
#  [ 0.19641941]]
# --------
# perturbed_perp_uz=[-29.26866166]
# [0.63368233]
# [0.73599395]
# [-0.23824276]
# --------
# [5.43184002]
# ------
# [[ 3.44206106]
#  [ 3.99780137]
#  [-1.29409654]]
# --------
# perturbed_perp_uz=[48.57202012]
# [0.62810432]
# [0.74202053]
# [-0.23428721]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.61712789]
# [0.75245689]
# [-0.2301343]
# --------
# [-19.58333518]
# ------
# [[-12.08542231]
#  [-14.73561548]
#  [  4.5067972 ]]
# --------
# perturbed_perp_uz=[-9.43215014]
# [0.61743033]
# [0.7559339]
# [-0.21758614]
# --------
# [-12.48175195]
# ------
# [[-7.70661224]
#  [-9.4353794 ]
#  [ 2.71585624]]
# --------
# perturbed_perp_uz=[52.76797921]
# [0.6214299]
# [0.75731345]
# [-0.20075162]
# --------
# [11.13418049]
# ------
# [[ 6.91911265]
#  [ 8.43206469]
#  [-2.2352048 ]]
# --------
# perturbed_perp_uz=[31.15470178]
# [0.62575734]
# [0.75643741]
# [-0.19034233]
# --------
# [7.47345935]
# ------
# [[ 4.67657205]
#  [ 5.6532042 ]
#  [-1.42251563]]
# --------
# perturbed_perp_uz=[-33.50203213]
# [0.64340875]
# [0.74214153]
# [-0.18775282]
# --------
# [23.72296424]
# ------
# [[15.26356281]
#  [17.60579707]
#  [-4.45405346]]
# --------
# perturbed_perp_uz=[29.18619747]
# [0.64166627]
# [0.73743746]
# [-0.2108326]
# --------
# [9.5553628]
# ------
# [[ 6.13135402]
#  [ 7.04648249]
#  [-2.01458201]]
# --------
# perturbed_perp_uz=[13.37922842]
# [0.63352001]
# [0.73742032]
# [-0.23422993]
# --------
# [-13.53169704]
# ------
# [[-8.57260091]
#  [-9.97854838]
#  [ 3.16952848]]
# --------
# perturbed_perp_uz=[-37.42510477]
# [0.64795277]
# [0.72199515]
# [-0.24265244]
# --------
# [14.98957971]
# ------
# [[ 9.71253977]
#  [10.82240381]
#  [-3.63725816]]
# --------
# perturbed_perp_uz=[24.38819563]
# [0.65975801]
# [0.70678744]
# [-0.2552859]
# --------
# [14.57892588]
# ------
# [[ 9.6185631 ]
#  [10.30420166]
#  [-3.72179416]]
# --------
# perturbed_perp_uz=[-12.7447703]
# [0.66169731]
# [0.69733962]
# [-0.27545259]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.66363384]
# [0.68907253]
# [-0.29115147]
# --------
# [-9.21793317]
# ------
# [[-6.11733237]
#  [-6.35182451]
#  [ 2.68381482]]
# --------
# perturbed_perp_uz=[38.89087702]
# [0.6709008]
# [0.68036057]
# [-0.29496037]
# --------
# [-9.03752723]
# ------
# [[-6.06328423]
#  [-6.14877714]
#  [ 2.66571237]]
# --------
# perturbed_perp_uz=[-10.43604396]
# [0.66814607]
# [0.67949668]
# [-0.30309254]
# --------
# [-5.66115014]
# ------
# [[-3.78247522]
#  [-3.84673275]
#  [ 1.71585236]]
# --------
# perturbed_perp_uz=[-53.05661921]
# [0.70156856]
# [0.64811695]
# [-0.29621948]
# --------
# [-1.07738652]
# ------
# [[-0.75586051]
#  [-0.69827246]
#  [ 0.31914287]]
# --------
# perturbed_perp_uz=[36.19204728]
# [0.75159717]
# [0.59750038]
# [-0.27945481]
# --------
# [-22.3159555]
# ------
# [[-16.77260904]
#  [-13.33379185]
#  [  6.23630102]]
# --------
# perturbed_perp_uz=[-6.24092645]
# [0.78198364]
# [0.56606448]
# [-0.26090725]
# --------
# [12.63815361]
# ------
# [[ 9.88282933]
#  [ 7.15400988]
#  [-3.29738588]]
# --------
# perturbed_perp_uz=[-46.70668144]
# [0.81024968]
# [0.53270068]
# [-0.24438788]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.83317701]
# [0.49755256]
# [-0.24136596]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.83546969]
# [0.48272772]
# [-0.26261061]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.84273504]
# [0.44002482]
# [-0.31012225]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.84750579]
# [0.38762581]
# [-0.36260195]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.8073605]
# [0.037662]
# [-0.58885533]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.6201216]
# [-0.26828287]
# [-0.73720656]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.56604789]
# [-0.3238043]
# [-0.75811646]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.26016249]
# [-0.47646304]
# [-0.83982049]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [0.17288948]
# [-0.66628198]
# [-0.72538097]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.14727971]
# [-0.90031147]
# [-0.40957044]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.18964556]
# [-0.91601825]
# [-0.35347578]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.31411109]
# [-0.92339837]
# [-0.22061205]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.35892797]
# [-0.89009092]
# [-0.28090721]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.35510455]
# [-0.89231136]
# [-0.27871346]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.37639469]
# [-0.88623431]
# [-0.27002924]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.37134366]
# [-0.89025973]
# [-0.26370722]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.36023716]
# [-0.89942436]
# [-0.2475177]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.36284331]
# [-0.90167022]
# [-0.23523508]
# --------
# [-11.781281]
# ------
# [[ 4.27475895]
#  [10.62283029]
#  [ 2.77137055]]
# --------
# perturbed_perp_uz=[7.10337878]
# [-0.3524321]
# [-0.91279951]
# [-0.20637021]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.35531888]
# [-0.91633549]
# [-0.18460162]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.3702657]
# [-0.91414913]
# [-0.16502931]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.37392005]
# [-0.91493758]
# [-0.15189806]
# --------
# [27.24300502]
# ------
# [[-10.18670576]
#  [-24.92564912]
#  [ -4.13815956]]
# --------
# perturbed_perp_uz=[-47.16590951]
# [-0.36497564]
# [-0.92101381]
# [-0.13611148]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.37662299]
# [-0.91910474]
# [-0.11576526]
# --------
# [-0.00756398]
# ------
# [[0.00284877]
#  [0.00695209]
#  [0.00087565]]
# --------
# perturbed_perp_uz=[13.47997669]
# [-0.39718511]
# [-0.9122904]
# [-0.09985095]
# --------
# [15.97122194]
# ------
# [[ -6.34353156]
#  [-14.57039246]
#  [ -1.59474176]]
# --------
# perturbed_perp_uz=[-57.23506514]
# [-0.41353446]
# [-0.90687729]
# [-0.08101133]
# --------
# [-28.78672021]
# ------
# [[11.90430086]
#  [26.10602273]
#  [ 2.3320504 ]]
# --------
# perturbed_perp_uz=[7.18637063]
# [-0.43932639]
# [-0.89593565]
# [-0.06551052]
# --------
# [-8.22044002]
# ------
# [[3.61145624]
#  [7.3649853 ]
#  [0.53852526]]
# --------
# perturbed_perp_uz=[-21.3693206]
# [-0.46284071]
# [-0.88490449]
# [-0.05217784]
# --------
# [4.28022074]
# ------
# [[-1.98106039]
#  [-3.78758654]
#  [-0.22333266]]
# --------
# perturbed_perp_uz=[-69.74613034]
# [-0.48277622]
# [-0.87475967]
# [-0.04150482]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.49412049]
# [-0.86900389]
# [-0.02602286]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.49864854]
# [-0.86661692]
# [-0.01802091]
# --------
# [22.06844469]
# ------
# [[-11.00439764]
#  [-19.12488754]
#  [ -0.39769349]]
# --------
# perturbed_perp_uz=[4.56644865]
# [-0.49555993]
# [-0.86842397]
# [-0.01612973]
# --------
# [21.71562268]
# ------
# [[-10.76139244]
#  [-18.85836721]
#  [ -0.3502672 ]]
# --------
# perturbed_perp_uz=[17.31287758]
# [-0.49107713]
# [-0.87091215]
# [-0.01884913]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.4880717]
# [-0.87254055]
# [-0.02142464]
# --------
# [10.94869]
# ------
# [[-5.34374569]
#  [-9.55317595]
#  [-0.23457172]]
# --------
# perturbed_perp_uz=[-0.30797324]
# [-0.48208898]
# [-0.87585254]
# [-0.02173816]
# --------
# [-27.97701396]
# ------
# [[13.48741017]
#  [24.50373865]
#  [ 0.6081688 ]]
# --------
# perturbed_perp_uz=[30.33046512]
# [-0.47224792]
# [-0.8811543]
# [-0.02343094]
# --------
# [-1.86207184]
# ------
# [[0.87935956]
#  [1.6407726 ]
#  [0.04363009]]
# --------
# perturbed_perp_uz=[-57.57284469]
# [-0.45840076]
# [-0.88842686]
# [-0.02380037]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.45895264]
# [-0.88787645]
# [-0.03221623]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.47888702]
# [-0.87732022]
# [-0.03124817]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.49684784]
# [-0.86739497]
# [-0.02771617]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.51117353]
# [-0.85902317]
# [-0.02794295]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.51890972]
# [-0.85433784]
# [-0.02897505]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.52452194]
# [-0.85087135]
# [-0.02991107]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.5336235]
# [-0.8451445]
# [-0.03125268]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.54003763]
# [-0.84092303]
# [-0.03475349]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.53422395]
# [-0.84455679]
# [-0.03644999]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.51014166]
# [-0.85919936]
# [-0.03914011]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.50197813]
# [-0.86389258]
# [-0.04132281]
# ...
# [-0.45432095]
# [-0.83174362]
# [-0.31905333]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.44998954]
# [-0.83407202]
# [-0.31911328]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.44313999]
# [-0.83692558]
# [-0.32122036]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.43903914]
# [-0.83752269]
# [-0.32526969]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.43033687]
# [-0.84145484]
# [-0.3267475]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.4206959]
# [-0.84478529]
# [-0.3306853]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.41993575]
# [-0.84326079]
# [-0.3355074]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.42123365]
# [-0.84199056]
# [-0.33706693]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.41775943]
# [-0.84266457]
# [-0.33969616]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.41515997]
# [-0.84373099]
# [-0.34023552]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.41493578]
# [-0.84427937]
# [-0.33914694]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.4118945]
# [-0.84538913]
# [-0.34008842]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.40810127]
# [-0.84667576]
# [-0.34145792]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.40460168]
# [-0.8482295]
# [-0.34176629]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.40071783]
# [-0.84963651]
# [-0.34284548]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.39680146]
# [-0.85103554]
# [-0.34392892]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.39320888]
# [-0.85193926]
# [-0.34581249]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.39159662]
# [-0.85198978]
# [-0.3475133]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.39001511]
# [-0.85219671]
# [-0.34878215]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.38784382]
# [-0.85308795]
# [-0.34902453]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.38594713]
# [-0.85390221]
# [-0.34913584]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.38381928]
# [-0.85428321]
# [-0.35054665]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.38323259]
# [-0.85421746]
# [-0.35134785]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.38302709]
# [-0.85442341]
# [-0.35107106]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.38041964]
# [-0.85615894]
# [-0.34967523]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.37653613]
# [-0.85815646]
# [-0.34898143]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.37114172]
# [-0.86071525]
# [-0.34845816]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.36711784]
# [-0.86293522]
# [-0.34722801]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.36704359]
# [-0.8635905]
# [-0.34567392]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.36644261]
# [-0.8645421]
# [-0.34392844]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.36346338]
# [-0.86654831]
# [-0.34203566]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.3593057]
# [-0.86907658]
# [-0.34000781]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.35529184]
# [-0.87139395]
# [-0.33829025]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.35144842]
# [-0.87341577]
# [-0.33708886]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.34720699]
# [-0.87552178]
# [-0.33601923]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.34487602]
# [-0.8767284]
# [-0.3352728]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.34232231]
# [-0.87797756]
# [-0.33462043]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.33940848]
# [-0.87954382]
# [-0.33347345]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.33742157]
# [-0.88065113]
# [-0.33256619]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.3354916]
# [-0.88154027]
# [-0.33216281]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.33300535]
# [-0.88291553]
# [-0.33100996]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.32664586]
# [-0.88554864]
# [-0.33031212]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.32119565]
# [-0.88770571]
# [-0.32986654]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.31903184]
# [-0.88867787]
# [-0.32934833]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.31810449]
# [-0.8890194]
# [-0.32932363]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.31322058]
# [-0.8907594]
# [-0.32930313]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.30827724]
# [-0.89240376]
# [-0.32951581]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.30782614]
# [-0.89265718]
# [-0.329251]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.30851849]
# [-0.89193519]
# [-0.33055704]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.30802353]
# [-0.89113879]
# [-0.33315636]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.30647034]
# [-0.89098816]
# [-0.3349866]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.30867087]
# [-0.89016653]
# [-0.33515048]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.3119416]
# [-0.88938419]
# [-0.33419786]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.31328177]
# [-0.88905649]
# [-0.33381595]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.31628413]
# [-0.8887244]
# [-0.33186338]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.31817163]
# [-0.88897038]
# [-0.32939105]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.32020528]
# [-0.88908175]
# [-0.32711194]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.32173033]
# [-0.88948967]
# [-0.32449612]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.32304018]
# [-0.890386]
# [-0.32071453]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.32477876]
# [-0.89137799]
# [-0.31617089]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.32622231]
# [-0.89251568]
# [-0.31143983]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.32690245]
# [-0.89370179]
# [-0.30729774]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.3261415]
# [-0.89543516]
# [-0.30303068]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.32490558]
# [-0.8972242]
# [-0.29904029]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.3240187]
# [-0.89862122]
# [-0.29579011]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.32311319]
# [-0.90013469]
# [-0.29215647]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.32219268]
# [-0.90153516]
# [-0.28883601]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.32226251]
# [-0.90231836]
# [-0.28630135]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.32268293]
# [-0.90344553]
# [-0.28224441]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.32330904]
# [-0.9044511]
# [-0.2782795]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.32368928]
# [-0.90523919]
# [-0.27525853]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.3241161]
# [-0.90626058]
# [-0.27136785]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.32381913]
# [-0.90749114]
# [-0.26758365]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.32350664]
# [-0.90871348]
# [-0.26378642]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.32436973]
# [-0.90936732]
# [-0.2604522]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.3241259]
# [-0.91044627]
# [-0.25696302]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.32261197]
# [-0.91237405]
# [-0.25198234]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.32214293]
# [-0.91360584]
# [-0.24808931]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.3251578]
# [-0.91377275]
# [-0.243499]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.32768451]
# [-0.91368082]
# [-0.24043758]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.33353616]
# [-0.91312675]
# [-0.23442091]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.3371085]
# [-0.91308824]
# [-0.22940732]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.33791372]
# [-0.91315383]
# [-0.227957]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.33918326]
# [-0.9133972]
# [-0.22507835]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.53650182]
# [-0.82853944]
# [-0.16027537]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.53677296]
# [-0.82829145]
# [-0.16064891]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.5360709]
# [-0.82830933]
# [-0.16288538]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.53602703]
# [-0.82824167]
# [-0.16337307]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.53687397]
# [-0.8271478]
# [-0.16611099]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.53758634]
# [-0.82659518]
# [-0.16655732]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.53803081]
# [-0.82617506]
# [-0.16720534]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.53821459]
# [-0.82591739]
# [-0.16788544]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.53842462]
# [-0.8256808]
# [-0.16837502]
# --------
# [-2.89071072]
# ------
# [[1.5564298 ]
#  [2.38680434]
#  [0.48672348]]
# --------
# perturbed_perp_uz=[40.6162725]
# [-0.53841876]
# [-0.82557634]
# [-0.16890513]
# --------
# [20.43939454]
# ------
# [[-11.00495342]
#  [-16.87428059]
#  [ -3.45231861]]
# --------
# perturbed_perp_uz=[37.99212703]
# [-0.53851731]
# [-0.82540743]
# [-0.16941569]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.5389595]
# [-0.82502353]
# [-0.16987886]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.5394718]
# [-0.82463063]
# [-0.17016024]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.54000604]
# [-0.82423783]
# [-0.17036866]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.5406089]
# [-0.82380571]
# [-0.1705467]
# --------
# [21.07707656]
# ------
# [[-11.39445512]
#  [-17.36341595]
#  [ -3.59462588]]
# --------
# perturbed_perp_uz=[-42.97464359]
# [-0.5412973]
# [-0.82331757]
# [-0.17072028]
# --------
# [5.787191]
# ------
# [[-3.13259087]
#  [-4.76469602]
#  [-0.98799087]]
# --------
# perturbed_perp_uz=[34.42587915]
# [-0.54191597]
# [-0.82287187]
# [-0.17090634]
# --------
# [-13.47570651]
# ------
# [[ 7.30270052]
#  [11.08877976]
#  [ 2.30308371]]
# --------
# perturbed_perp_uz=[-27.6063754]
# [-0.5424341]
# [-0.8224609]
# [-0.17124052]
# --------
# [-5.32708481]
# ------
# [[2.88959244]
#  [4.38131897]
#  [0.91221278]]
# --------
# perturbed_perp_uz=[-8.64710638]
# [-0.54243903]
# [-0.82235846]
# [-0.17171624]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.54185187]
# [-0.82258695]
# [-0.17247394]
# --------
# [3.51143348]
# ------
# [[-1.90267679]
#  [-2.88845937]
#  [-0.60563075]]
# --------
# perturbed_perp_uz=[5.97893879]
# [-0.5409035]
# [-0.82295484]
# [-0.17369152]
# --------
# [-16.75039349]
# ------
# [[ 9.06034642]
#  [13.78481731]
#  [ 2.90940138]]
# --------
# perturbed_perp_uz=[24.99740905]
# [-0.53999798]
# [-0.82331667]
# [-0.17479087]
# --------
# [-21.26330044]
# ------
# [[11.4821393 ]
#  [17.50642964]
#  [ 3.7166307 ]]
# --------
# perturbed_perp_uz=[52.05485308]
# [-0.53921823]
# [-0.82363694]
# [-0.17568692]
# --------
# [6.40928196]
# ------
# [[-3.4560017 ]
#  [-5.27892135]
#  [-1.12602703]]
# --------
# perturbed_perp_uz=[28.25154756]
# [-0.53839833]
# [-0.82399544]
# [-0.17651843]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.53762159]
# [-0.82435158]
# [-0.17722162]
# --------
# [-1.63631963]
# ------
# [[0.87972076]
#  [1.34890266]
#  [0.28999121]]
# --------
# perturbed_perp_uz=[19.99009684]
# [-0.53701413]
# [-0.82461392]
# [-0.17784182]
# --------
# [18.0205148]
# ------
# [[ -9.67727101]
#  [-14.85996731]
#  [ -3.20480121]]
# --------
# perturbed_perp_uz=[-1.9767565]
# [-0.53686902]
# [-0.82458728]
# [-0.17840255]
# --------
# [-5.57563852]
# ------
# [[2.99338758]
#  [4.59760062]
#  [0.99470812]]
# --------
# perturbed_perp_uz=[-34.57342313]
# [-0.5370251]
# [-0.82438817]
# [-0.17885242]
# --------
# [25.18561941]
# ------
# [[-13.52530972]
#  [-20.76272672]
#  [ -4.50450901]]
# --------
# perturbed_perp_uz=[-10.92175311]
# [-0.53737137]
# [-0.82412476]
# [-0.17902621]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.53764827]
# [-0.82386542]
# [-0.17938814]
# --------
# [4.45314888]
# ------
# [[-2.3942278 ]
#  [-3.66879537]
#  [-0.79884209]]
# --------
# perturbed_perp_uz=[4.36457606]
# [-0.53784665]
# [-0.8236349]
# [-0.17985142]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.53803658]
# [-0.82338897]
# [-0.18040854]
# --------
# [0.70327469]
# ------
# [[-0.37838751]
#  [-0.57906863]
#  [-0.12687676]]
# --------
# perturbed_perp_uz=[-11.54895408]
# [-0.53809242]
# [-0.82318924]
# [-0.18115191]
# --------
# [-5.09989938]
# ------
# [[2.74421722]
#  [4.19818231]
#  [0.92385651]]
# --------
# perturbed_perp_uz=[-20.79458202]
# [-0.53805754]
# [-0.82304334]
# [-0.18191685]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.53799145]
# [-0.82293887]
# [-0.1825837]
# --------
# [-21.8444928]
# ------
# [[11.75215042]
#  [17.97668231]
#  [ 3.98844826]]
# --------
# perturbed_perp_uz=[6.26129104]
# [-0.5378197]
# [-0.82291504]
# [-0.1831961]
# --------
# [-1.14410611]
# ------
# [[0.61532281]
#  [0.94150213]
#  [0.20959578]]
# --------
# perturbed_perp_uz=[-3.10721699]
# [-0.5375878]
# [-0.8229318]
# [-0.18380047]
# --------
# [-28.97434102]
# ------
# [[15.57625213]
#  [23.84390665]
#  [ 5.3254974 ]]
# --------
# perturbed_perp_uz=[17.40568497]
# [-0.53739414]
# [-0.82293353]
# [-0.18435818]
# --------
# [-1.70712218]
# ------
# [[0.91739746]
#  [1.40484809]
#  [0.31472193]]
# --------
# perturbed_perp_uz=[-9.86540181]
# [-0.5372166]
# [-0.8229133]
# [-0.18496491]
# --------
# [48.91358046]
# ------
# [[-26.27718762]
#  [-40.25163604]
#  [ -9.04729577]]
# --------
# perturbed_perp_uz=[-11.29769122]
# [-0.53707169]
# [-0.8228828]
# [-0.1855206]
# --------
# [-5.17776005]
# ------
# [[2.78082833]
#  [4.26068971]
#  [0.96058114]]
# --------
# perturbed_perp_uz=[-14.85404865]
# [-0.53695186]
# [-0.82283209]
# [-0.18609154]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.53678447]
# [-0.82280916]
# [-0.1866749]
# --------
# [nan]
# ------
# [[nan]
#  [nan]
#  [nan]]
# --------
# perturbed_perp_uz=[nan]
# [-0.53660876]
# [-0.82278186]
# [-0.18729934]
# --------
# [5.28139434]
# ------
# [[-2.83404247]
#  [-4.34543547]
#  [-0.98920167]]
# --------
# perturbed_perp_uz=[0.19747424]

# %%
startOrbit = 35
endOrbit = 54
save_pickles = True
mu_0 = np.pi*4e-7
gamma = 5/3
k_B = 1.38e-23

#window_size = 30

for i in range(startOrbit, endOrbit+1):
    print('grabbing mean mag orbit ' + str(i))
    filename = '/home/mtfranciscovich/Juno-codes/jss_reduced_inbound_1s_means_4min_pickles/reduced_orbit_' +str(i) +'_4min_means_1s.pkl'
    picklefile = open(filename,'rb')
    mean_mag_data = pickle.load(picklefile)
    
    orbit_means = mean_mag_data
    
    
    print('grabbing mean v orbit ' + str(i))
    filename = '/home/mtfranciscovich/Juno-codes/test_fits_u_cart_means_4min/u_cart_means_4min_orbit_' +str(i) +'.pkl'
    picklefile = open(filename,'rb')
    mean_v_data = pickle.load(picklefile)
    
    all_dates = orbit_means.index.union(fits_data.index)

    reindexed_orbit_means = orbit_means.reindex(all_dates)
    reindexed_fits_data = fits_data.reindex(all_dates)

    combined_current = reindexed_orbit_means.combine_first(reindexed_fits_data)
    
    

    beginning_of_orbit_data = orbit_means.index[0]
    end_of_orbit_data = orbit_means.index[-1]


    combined_updated_for_orbit = combined_current[beginning_of_orbit_data:end_of_orbit_data]


    print('grabbing delta densities')
    filename = '/home/mtfranciscovich/Juno-codes/code/delta_density_df.pkl'
    picklefile = open(filename,'rb')
    delta_density_data = pickle.load(picklefile)
    
    print('Calculating ratios...')
    

    ux_pert_perp = mean_v_data['u_x_pert_perp']*1e3
    uy_pert_perp = mean_v_data['u_y_pert_perp']*1e3
    uz_pert_perp = mean_v_data['u_z_pert_perp']*1e3
    
    delta_v_perp_mag = np.sqrt(ux_pert_perp**2 + uy_pert_perp**2 + uz_pert_perp**2)
    

    
    Bx_total = mean_mag_data['MEAN_BX']*(10**-9)
    By_total = mean_mag_data['MEAN_BY']*(10**-9)
    Bz_total = mean_mag_data['MEAN_BZ']*(10**-9)
    
    Bx_pert_perp = mean_mag_data['B_x_pert_perp']*(10**-9)
    By_pert_perp = mean_mag_data['B_y_pert_perp']*(10**-9)
    Bz_pert_perp = mean_mag_data['B_z_pert_perp']*(10**-9)
    
    B_pert_perp_mag = np.sqrt(Bx_pert_perp**2 + By_pert_perp**2 + Bz_pert_perp**2)
    
    Bx_pert_par = mean_mag_data['B_x_pert_par']*(10**-9)
    By_pert_par = mean_mag_data['B_y_pert_par']*(10**-9)
    Bz_pert_par = mean_mag_data['B_z_pert_par']*(10**-9)
    
    B_pert_par_mag = np.sqrt(Bx_pert_par**2 + By_pert_par**2 + Bz_pert_par**2)
    
    mean_vecs = mean_mag_data[['MEAN_BX','MEAN_BY','MEAN_BZ']]
    mean_magnitude  = np.sqrt(Bx_total**2 + By_total**2 + Bz_total**2)
    


    

    

    mean_density = delta_density_data['MEAN_density']*1e6
    mean_mass = delta_density_data['MEAN_mass']
    
    mean_temp = delta_density_data['MEAN_temperature']
    
    
    

    v_Alfven= (mean_magnitude)/np.sqrt(mu_0*mean_density) #does v_alfven need to be a vector quantity?]\
      
        
    v_S_squared =    gamma*mean_temp*11606*k_B/mean_mass
    
    delta_density = delta_density_data['density_pert']*1e6
    
    delta_density = delta_density + v_Alfven*0
    v_S_squared = v_S_squared + v_Alfven*0
    
    mean_density = mean_density + v_Alfven*0
    
    delta_v_perp_mag = delta_v_perp_mag + v_Alfven*0+mean_magnitude*0+mean_density*0
    
    compression_df = pd.DataFrame({'delta_density':delta_density, 'v_Alfven':v_Alfven, 'v_S':np.sqrt(v_S_squared), 'delta_v_perp_mag':delta_v_perp_mag, 'MEAN_density':mean_density, 'B_pert_perp_mag':B_pert_perp_mag, 'B_pert_par_mag':B_pert_par_mag, 'MEAN_B':mean_magnitude})
    
 


    
    
    
    
    print('Combine with z_mag  and R array ...')
    
    filename = '/home/mtfranciscovich/Juno-codes/reduced_inbound_1s_pickles/reduced_orbit_' +str(i) +'_1s.pkl'
    picklefile = open(filename,'rb')
    mag_data_mag_frame = pickle.load(picklefile)
    z_mag_info = mag_data_mag_frame['Z_MAG']
    R_info = mag_data_mag_frame['R']
    
    compression_df['Z_MAG'] = z_mag_info
    compression_df['R'] = R_info
    

    if save_pickles:
        compression_df.to_pickle('/home/mtfranciscovich/Juno-codes/compression_dfs_by_orbit/compression_df_orbit_' + str(i) + '.pkl')

# %%
startOrbit = 36
endOrbit = 54
save_pickles = True
mu_0 = np.pi*4e-7

window_size = 30

print('grabbing mean density')
filename = '/home/mtfranciscovich/Juno-codes/code/delta_density_df_2.pkl'
picklefile = open(filename,'rb')
mean_density_data = pickle.load(picklefile)

for i in range(startOrbit, endOrbit+1):
    if i ==49:
        continue
    print('grabbing mean mag orbit ' + str(i))
    #filename = '/home/mtfranciscovich/Juno-codes/jss_downsampled_mag_pickles_10min/reduced_orbit_' +str(i) +'_10min_means_1s.pkl'
    filename = '/home/mtfranciscovich/Juno-codes/means_10min_reduced_inbound_1s_pickles_unit_z_mag_jss_downsampled/reduced_orbit_'+str(i)+'_1s.pkl'
    picklefile = open(filename,'rb')
    mean_mag_data = pickle.load(picklefile)
    
    orbit_means = mean_mag_data
    
    print('grabbing total mag orbit ' + str(i))
    filename = '/home/mtfranciscovich/Juno-codes/reduced_inbound_1s_pickles_unit_z_mag/reduced_orbit_'+str(i)+'_1s.pkl'
    picklefile = open(filename,'rb')
    total_mag_data = pickle.load(picklefile)
    
    
    #filename = '/home/mtfranciscovich/Juno-codes/reduced_inbound_1s_means_4min_pickles/reduced_orbit_' + str(i) + '_4min_means_1s.pkl'
    
    #picklefile = open(filename,'rb')
    #mean_mag_data_mag_coord = pickle.load(picklefile)
    
    #orbit_means_mag_cord = mean_mag_data_mag_coord
    
    
    
    print('grabbing mean v orbit ' + str(i))
    #filename = '/home/mtfranciscovich/Juno-codes/test_fits_u_cart_means_4min/u_cart_means_4min_orbit_' +str(i) +'.pkl'
    filename = '/home/mtfranciscovich/Juno-codes/updated_fits_u_cart_means_10min/u_cart_means_10min_orbit_' +str(i)+'.pkl'
    picklefile = open(filename,'rb')
    mean_v_data = pickle.load(picklefile)
    
    print('grabbing total v orbit ' + str(i))
    filename = '/home/mtfranciscovich/Juno-codes/fits_u_cart_pickles_updated/u_cart_orbit_'+str(i)+'.pkl'
    picklefile = open(filename,'rb')
    total_v_data = pickle.load(picklefile)
    

 
    
    all_dates = orbit_means.index.union(fits_data.index)

    reindexed_orbit_means = orbit_means.reindex(all_dates)
    reindexed_fits_data = fits_data.reindex(all_dates)

    combined_current = reindexed_orbit_means.combine_first(reindexed_fits_data)
    
    

    beginning_of_orbit_data = orbit_means.index[0]
    end_of_orbit_data = orbit_means.index[-1]
    
    
    print('cleaning mean density')
    
    delta_density_data = mean_density_data[beginning_of_orbit_data:end_of_orbit_data]


    combined_updated_for_orbit = combined_current[beginning_of_orbit_data:end_of_orbit_data]

    
    print('Calculating dot prod and helicity...')
    

    ux_pert_perp = mean_v_data['u_x_pert_perp']*1e3
    uy_pert_perp = mean_v_data['u_y_pert_perp']*1e3
    uz_pert_perp = mean_v_data['u_z_pert_perp']*1e3
    
    Bx_pert_perp = mean_mag_data['B_x_pert_perp']*(10**-9)
    By_pert_perp = mean_mag_data['B_y_pert_perp']*(10**-9)
    Bz_pert_perp = mean_mag_data['B_z_pert_perp']*(10**-9)
    
    Bx_total = mean_mag_data['MEAN_BX']*(10**-9)
    By_total = mean_mag_data['MEAN_BY']*(10**-9)
    Bz_total = mean_mag_data['MEAN_BZ']*(10**-9)
    
    
    #Bx_mag_coord = mean_mag_data_mag_coord['MEAN_BX']*(10**-9)
    #By_mag_coord = mean_mag_data_mag_coord['MEAN_BY']*(10**-9)
    #Bz_mag_coord = mean_mag_data_mag_coord['MEAN_BZ']*(10**-9)
    
    mean_magnitude_mag_coord = np.sqrt(Bx_total**2+By_total**2+Bz_total**2)
    
    unitz_x = total_mag_data['UNITZ_X']
    unitz_y = total_mag_data['UNITZ_Y']
    unitz_z = total_mag_data['UNITZ_Z']
 
    
    cos_theta = (Bx_total*unitz_x+By_total*unitz_y+Bz_total*unitz_z)/mean_magnitude_mag_coord
    
    

    
    mean_vecs = mean_mag_data[['MEAN_BX','MEAN_BY','MEAN_BZ']]
    mean_magnitude  = np.sqrt(Bx_total**2 + By_total**2 + Bz_total**2)
    
    #B0 = np.dot((mean_vecs).to_numpy(), parallel_hat)
    
    B_tot_mag = np.sqrt(Bx_total**2 + By_total**2 + Bz_total**2)
    
    #test = Bx_total/B_tot_mag
    
    mean_density = delta_density_data['MEAN_density']*1e6
    mean_mass = delta_density_data['MEAN_mass']
    
    mean_temp = delta_density_data['MEAN_temperature']
    
    
    

    v_Alfven= (mean_magnitude)/np.sqrt(mu_0*mean_density)
    
    
    '''
    n = combined_updated_for_orbit['      "n"'] 
    m16 = combined_updated_for_orbit['r[MQ16]']
    mo = combined_updated_for_orbit['r[O2+]']
    ms = combined_updated_for_orbit['r[S+]']
    ms3 = combined_updated_for_orbit['r[S3+]']
    
    m16_factor = 5.32*10**-26 + 2.65*10**-26
    mo2_factor = 5.31*10**-26
    ms_factor = 5.32*10**-26
    ms3_factor = 5.32*10**-26
    

    m = m16*m16_factor + mo*mo2_factor +ms*ms_factor+ms3*ms3_factor

    density = m * n*1e6
    
    '''

    '''
    v_Alfven_x = (Bx_total)/np.sqrt(mu_0*density) #does v_alfven need to be a vector quantity?
    v_Alfven_y = (By_total)/np.sqrt(mu_0*density) #does v_alfven need to be a vector quantity?
    v_Alfven_z = (Bz_total)/np.sqrt(mu_0*density) #does v_alfven need to be a vector quantity?
    '''
    
    Bx_pert_perp_norm = Bx_pert_perp/mean_magnitude
    By_pert_perp_norm = By_pert_perp/mean_magnitude
    Bz_pert_perp_norm = Bz_pert_perp/mean_magnitude
    
    ux_pert_perp_norm = ux_pert_perp/v_Alfven
    uy_pert_perp_norm = uy_pert_perp/v_Alfven
    uz_pert_perp_norm = uz_pert_perp/v_Alfven

    

    
    
    dot_prod_for_calc = ux_pert_perp*Bx_pert_perp + uy_pert_perp*By_pert_perp + uz_pert_perp*Bz_pert_perp
    
    
    factor = np.sqrt(Bx_total**2 + By_total**2 + Bz_total**2)*(1/mu_0)
    
    delta_dot_prod = (-1)*(dot_prod_for_calc)*(factor)
    
    Helicity = dot_prod_for_calc/2
    
    norm_Helicity_num = ux_pert_perp_norm*Bx_pert_perp_norm + uy_pert_perp_norm*By_pert_perp_norm + uz_pert_perp_norm*Bz_pert_perp_norm

    
    
    delta_vperp_squared_norm = ux_pert_perp_norm**2+uy_pert_perp_norm**2+uz_pert_perp_norm**2
    delta_Bperp_squared_norm = Bx_pert_perp_norm**2+By_pert_perp_norm**2+Bz_pert_perp_norm**2
    
    delta_energy_norm = 0.5*(delta_vperp_squared_norm+delta_Bperp_squared_norm)
    
    norm_Helicity = norm_Helicity_num/delta_energy_norm
    
    
    residual_energy_num = delta_vperp_squared_norm - delta_Bperp_squared_norm
    
    residual_energy_denom = delta_vperp_squared_norm + delta_Bperp_squared_norm
    
    residual_energy_Norm = residual_energy_num/residual_energy_denom
    
    delta_vperp_magnitude = np.sqrt(ux_pert_perp**2+uy_pert_perp**2+uz_pert_perp**2)
    
    delta_Bperp_magnitude = np.sqrt(Bx_pert_perp**2+By_pert_perp**2+Bz_pert_perp**2)
    
    delta_v_alfven = delta_Bperp_magnitude/np.sqrt(mu_0*(delta_density_data['density_pert']*1e6))
    
    vx_jss = total_v_data['UX']*1e3
    vy_jss = total_v_data['UY']*1e3
    vz_jss = total_v_data['UZ']*1e3
    
    Bx_jss = total_mag_data['BX_JSS']*1e-9
    By_jss = total_mag_data['BY_JSS']*1e-9
    Bz_jss = total_mag_data['BZ_JSS']*1e-9
    
    
    v_cross_b_x = (vy_jss*Bz_jss - By_jss*vz_jss)
    v_cross_b_y = -(vx_jss*Bz_jss - Bx_jss*vz_jss)
    v_cross_b_z = (vx_jss*By_jss - Bx_jss*vy_jss)
    
    Sx_jss = (-(v_cross_b_y*Bz_jss - By_jss*v_cross_b_z))/mu_0
    Sy_jss = (v_cross_b_x*Bz_jss - Bx_jss*v_cross_b_z)/mu_0
    Sz_jss = -(v_cross_b_x*By_jss - Bx_jss*v_cross_b_y)/mu_0
    
    
    x = total_mag_data['X_JSS']
    y = total_mag_data['Y_JSS']
    
    phi = np.arctan2(y,x)
    
    S_r = Sx_jss*np.cos(phi) + Sy_jss*np.sin(phi)
    S_phi = -np.sin(phi)*Sx_jss + Sy_jss*np.cos(phi)
    

    
    S_dot_zmag = Sx_jss*unitz_x+Sy_jss*unitz_y+Sz_jss*unitz_z
    
    energy_df = pd.DataFrame({'delta_dot_prod': delta_dot_prod , 'Helicity': Helicity, 'delta_energy': delta_energy_norm, 'norm_Helicity': norm_Helicity, 'norm_residual_energy': residual_energy_Norm, 'v_Alfven': v_Alfven, 'cos_theta':cos_theta, 'delta_vperp_squared_norm': delta_vperp_squared_norm, 'delta_Bperp_squared_norm': delta_Bperp_squared_norm, 'norm_helicity_num': norm_Helicity_num,'S_r':S_r, 'S_phi':S_phi,'S_z':Sz_jss,'S_dot_zmag':S_dot_zmag,'phi':phi})  
    print('Combine with z_mag  and R array ...')
    
    #filename = '/home/mtfranciscovich/Juno-codes/reduced_inbound_1s_pickles/reduced_orbit_' +str(i) +'_1s.pkl'
    #picklefile = open(filename,'rb')
    #mag_data_mag_frame = pickle.load(picklefile)
    z_mag_info = total_mag_data['Z_MAG']
    Rj_km = 7.14e4
    R_info = np.sqrt(total_mag_data['X_JSS']**2+total_mag_data['Y_JSS']**2)/Rj_km    
    energy_df['Z_MAG'] = z_mag_info
    energy_df['R'] = R_info
    
    energy_df = energy_df.dropna()
    mean_energy_data = pd.DataFrame({'MEAN_delta_dot_prod': [], 'MEAN_Helicity': [], 'MEAN_delta_energy': [], 'MEAN_norm_Helicity': [], 'MEAN_norm_residual_energy': [], 'MEAN_cos_theta': [], 'residual_energy_test': [], 'norm_helicity_test': [], 'MEAN_S_r':[], 'MEAN_S_phi':[], 'MEAN_S_z':[], 'MEAN_S_dot_zmag':[]})

    finish_datetime = (energy_df.index[-1]
- timedelta(minutes=np.floor(window_size/2)))
    for datetime_index in energy_df.index:
        start_datetime = datetime_index
        end_datetime = start_datetime + timedelta(minutes=window_size)
        mean_datetime_index = pd.DatetimeIndex([
        (start_datetime + timedelta(minutes=round(window_size/2))).isoformat()
        ])
        temp_mean_delta_dot_prod = np.nanmean(energy_df[start_datetime.isoformat(): end_datetime.isoformat()].delta_dot_prod)
        temp_mean_Helicity = np.nanmean(energy_df[start_datetime.isoformat(): end_datetime.isoformat()].Helicity)
        temp_mean_delta_energy = np.nanmean(energy_df[start_datetime.isoformat(): end_datetime.isoformat()].delta_energy)
        temp_mean_norm_Helicity = np.nanmean(energy_df[start_datetime.isoformat(): end_datetime.isoformat()].norm_Helicity)
        temp_mean_norm_residual_energy = np.nanmean(energy_df[start_datetime.isoformat(): end_datetime.isoformat()].norm_residual_energy)
        temp_mean_cos_theta = np.nanmean(energy_df[start_datetime.isoformat(): end_datetime.isoformat()].cos_theta)
        
        
        temp_mean_vperp_squared_norm = np.nanmean(energy_df[start_datetime.isoformat(): end_datetime.isoformat()].delta_vperp_squared_norm)
        temp_mean_Bperp_squared_norm = np.nanmean(energy_df[start_datetime.isoformat(): end_datetime.isoformat()].delta_Bperp_squared_norm)
        
        temp_res_energy_num = temp_mean_vperp_squared_norm - temp_mean_Bperp_squared_norm
        temp_res_energy_denom = temp_mean_vperp_squared_norm + temp_mean_Bperp_squared_norm
        temp_mean_residual_energy_test = temp_res_energy_num/temp_res_energy_denom
        
        temp_mean_norm_hel_num = np.nanmean(energy_df[start_datetime.isoformat(): end_datetime.isoformat()].norm_helicity_num)
        temp_mean_norm_helicity_test = temp_mean_norm_hel_num/temp_res_energy_denom
        temp_mean_Bperp_squared_norm = np.nanmean(energy_df[start_datetime.isoformat(): end_datetime.isoformat()].delta_Bperp_squared_norm)
        temp_mean_S_r = np.nanmean(energy_df[start_datetime.isoformat(): end_datetime.isoformat()].S_r)
        temp_mean_S_phi = np.nanmean(energy_df[start_datetime.isoformat(): end_datetime.isoformat()].S_phi)
        temp_mean_S_z = np.nanmean(energy_df[start_datetime.isoformat(): end_datetime.isoformat()].S_z)
        temp_mean_S_dot_zmag = np.nanmean(energy_df[start_datetime.isoformat(): end_datetime.isoformat()].S_dot_zmag)
        
        mean_array_to_concat = pd.DataFrame(
        {'MEAN_delta_dot_prod': temp_mean_delta_dot_prod,
            'MEAN_Helicity': temp_mean_Helicity,
            'MEAN_delta_energy' : temp_mean_delta_energy,
            'MEAN_norm_Helicity' : temp_mean_norm_Helicity,
            'MEAN_norm_residual_energy': temp_mean_norm_residual_energy,
            'MEAN_cos_theta': temp_mean_cos_theta,
            'residual_energy_test': temp_mean_residual_energy_test,
            'norm_helicity_test': temp_mean_norm_helicity_test,
            'MEAN_S_r': temp_mean_S_r,
            'MEAN_S_phi': temp_mean_S_phi,
            'MEAN_S_z': temp_mean_S_z,
            'MEAN_S_dot_zmag': temp_mean_S_dot_zmag
            
            }, index=mean_datetime_index)
        mean_energy_data = pd.concat([mean_energy_data, mean_array_to_concat])
    
        if mean_datetime_index == finish_datetime:
            break
    energy_df = energy_df[mean_energy_data.index[0].isoformat(): 
                            mean_energy_data.index[-1].isoformat()]
    energy_df = pd.concat([energy_df, mean_energy_data], axis=1)

    if save_pickles:
        energy_df.to_pickle('/home/mtfranciscovich/Juno-codes/updated_energy_pickles_0423/energy_df_orbit_' + str(i) + '.pkl')

# %%
startOrbit = 23
endOrbit = 23
save_pickles = False
mu_0 = np.pi*4e-7
print(mu_0)
window_size = 30

print('grabbing mean density')
filename = '/home/mtfranciscovich/Juno-codes/all_fits_data_dfs/delta_density_df_2.pkl'
picklefile = open(filename,'rb')
mean_density_data = pickle.load(picklefile)

for i in range(startOrbit, endOrbit+1):
    if i ==49:
        continue
    print('grabbing mean mag orbit ' + str(i))
    #filename = '/home/mtfranciscovich/Juno-codes/jss_downsampled_mag_pickles_10min/reduced_orbit_' +str(i) +'_10min_means_1s.pkl'
    filename = '/home/mtfranciscovich/Juno-codes/raw_mag_data/reduced_inbound_1s_pickles_unit_z_mag/reduced_orbit_'+str(i)+'_1s.pkl'
    picklefile = open(filename,'rb')
    unit_vector_data = pickle.load(picklefile)
    print(unit_vector_data.columns)

    print('grabbing orbit ' + str(i))
    filename = '/home/mtfranciscovich/Juno-codes/mean_mag_data_4min/jss_reduced_inbound_1s_means_4min_pickles/reduced_orbit_' +str(i) +'_4min_means_1s.pkl'
    picklefile = open(filename,'rb')
    mag_data = pickle.load(picklefile)

    mean_mag_data = mag_data
    total_mag_data = mag_data
    
    orbit_means = mag_data
    
    print('grabbing total mag orbit ' + str(i))
    filename = '/home/mtfranciscovich/Juno-codes/raw_mag_data/reduced_inbound_1s_pickles_unit_z_mag/reduced_orbit_'+str(i)+'_1s.pkl'
    picklefile = open(filename,'rb')
    z_mag_data = pickle.load(picklefile)
    
    
    #filename = '/home/mtfranciscovich/Juno-codes/reduced_inbound_1s_means_4min_pickles/reduced_orbit_' + str(i) + '_4min_means_1s.pkl'
    
    #picklefile = open(filename,'rb')
    #mean_mag_data_mag_coord = pickle.load(picklefile)
    
    #orbit_means_mag_cord = mean_mag_data_mag_coord
    
    
    
    print('grabbing mean v orbit ' + str(i))
    #filename = '/home/mtfranciscovich/Juno-codes/test_fits_u_cart_means_4min/u_cart_means_4min_orbit_' +str(i) +'.pkl'
    filename = '/home/mtfranciscovich/Juno-codes/jso_mean_velos/orbit_' +str(i)+'.pkl'
    picklefile = open(filename,'rb')
    mean_v_data = pickle.load(picklefile)
    
    print('grabbing total v orbit ' + str(i))
    filename = '/home/mtfranciscovich/Juno-codes/jso_mean_velos/orbit_' +str(i)+'.pkl'
    picklefile = open(filename,'rb')
    total_v_data = pickle.load(picklefile)
    

 
    
    all_dates = orbit_means.index.union(fits_data.index)

    reindexed_orbit_means = orbit_means.reindex(all_dates)
    reindexed_fits_data = fits_data.reindex(all_dates)

    combined_current = reindexed_orbit_means.combine_first(reindexed_fits_data)
    
    

    beginning_of_orbit_data = orbit_means.index[0]
    end_of_orbit_data = orbit_means.index[-1]
    
    
    print('cleaning mean density')
    
    delta_density_data = mean_density_data[beginning_of_orbit_data:end_of_orbit_data]


    combined_updated_for_orbit = combined_current[beginning_of_orbit_data:end_of_orbit_data]

    
    print('Calculating dot prod and helicity...')
    

    ux_pert_perp = mean_v_data['u_x_pert_perp']*1e3
    uy_pert_perp = mean_v_data['u_y_pert_perp']*1e3
    uz_pert_perp = mean_v_data['u_z_pert_perp']*1e3
    
    Bx_pert_perp = mean_mag_data['B_x_pert_perp']*(10**-9)
    By_pert_perp = mean_mag_data['B_y_pert_perp']*(10**-9)
    Bz_pert_perp = mean_mag_data['B_z_pert_perp']*(10**-9)
    
    Bx_total = mean_mag_data['MEAN_BX']*(10**-9)
    By_total = mean_mag_data['MEAN_BY']*(10**-9)
    Bz_total = mean_mag_data['MEAN_BZ']*(10**-9)
    
    
    #Bx_mag_coord = mean_mag_data_mag_coord['MEAN_BX']*(10**-9)
    #By_mag_coord = mean_mag_data_mag_coord['MEAN_BY']*(10**-9)
    #Bz_mag_coord = mean_mag_data_mag_coord['MEAN_BZ']*(10**-9)
    
    mean_magnitude_mag_coord = np.sqrt(Bx_total**2+By_total**2+Bz_total**2)
    
    unitz_x = z_mag_data['UNITZ_X']
    unitz_y = z_mag_data['UNITZ_Y']
    unitz_z = z_mag_data['UNITZ_Z']
 
    
    cos_theta = (Bx_total*unitz_x+By_total*unitz_y+Bz_total*unitz_z)/mean_magnitude_mag_coord
    
    

    
    mean_vecs = mean_mag_data[['MEAN_BX','MEAN_BY','MEAN_BZ']]
    mean_magnitude  = np.sqrt(Bx_total**2 + By_total**2 + Bz_total**2)
    
    #B0 = np.dot((mean_vecs).to_numpy(), parallel_hat)
    
    B_tot_mag = np.sqrt(Bx_total**2 + By_total**2 + Bz_total**2)
    
    #test = Bx_total/B_tot_mag
    
    mean_density = delta_density_data['MEAN_density']*1e6
    #mean_mass = delta_density_data['MEAN_mass']
    
    #mean_temp = delta_density_data['MEAN_temperature']
    
    
    

    v_Alfven= (mean_magnitude)/np.sqrt(mu_0*mean_density)
    
    
    '''
    n = combined_updated_for_orbit['      "n"'] 
    m16 = combined_updated_for_orbit['r[MQ16]']
    mo = combined_updated_for_orbit['r[O2+]']
    ms = combined_updated_for_orbit['r[S+]']
    ms3 = combined_updated_for_orbit['r[S3+]']
    
    m16_factor = 5.32*10**-26 + 2.65*10**-26
    mo2_factor = 5.31*10**-26
    ms_factor = 5.32*10**-26
    ms3_factor = 5.32*10**-26
    

    m = m16*m16_factor + mo*mo2_factor +ms*ms_factor+ms3*ms3_factor

    density = m * n*1e6
    
    '''

    '''
    v_Alfven_x = (Bx_total)/np.sqrt(mu_0*density) #does v_alfven need to be a vector quantity?
    v_Alfven_y = (By_total)/np.sqrt(mu_0*density) #does v_alfven need to be a vector quantity?
    v_Alfven_z = (Bz_total)/np.sqrt(mu_0*density) #does v_alfven need to be a vector quantity?
    '''
    
    Bx_pert_perp_norm = Bx_pert_perp/mean_magnitude
    By_pert_perp_norm = By_pert_perp/mean_magnitude
    Bz_pert_perp_norm = Bz_pert_perp/mean_magnitude
    
    ux_pert_perp_norm = ux_pert_perp/v_Alfven
    uy_pert_perp_norm = uy_pert_perp/v_Alfven
    uz_pert_perp_norm = uz_pert_perp/v_Alfven

    

    
    
    dot_prod_for_calc = ux_pert_perp*Bx_pert_perp + uy_pert_perp*By_pert_perp + uz_pert_perp*Bz_pert_perp
    
    
    factor = np.sqrt(Bx_total**2 + By_total**2 + Bz_total**2)*(1/mu_0)
    
    delta_dot_prod = (-1)*(dot_prod_for_calc)*(factor)
    
    Helicity = dot_prod_for_calc/2
    
    norm_Helicity_num = ux_pert_perp_norm*Bx_pert_perp_norm + uy_pert_perp_norm*By_pert_perp_norm + uz_pert_perp_norm*Bz_pert_perp_norm

    
    
    delta_vperp_squared_norm = ux_pert_perp_norm**2+uy_pert_perp_norm**2+uz_pert_perp_norm**2
    delta_Bperp_squared_norm = Bx_pert_perp_norm**2+By_pert_perp_norm**2+Bz_pert_perp_norm**2
    
    delta_energy_norm = 0.5*(delta_vperp_squared_norm+delta_Bperp_squared_norm)
    
    norm_Helicity = norm_Helicity_num/delta_energy_norm
    
    
    residual_energy_num = delta_vperp_squared_norm - delta_Bperp_squared_norm
    
    residual_energy_denom = delta_vperp_squared_norm + delta_Bperp_squared_norm
    
    residual_energy_Norm = residual_energy_num/residual_energy_denom
    
    delta_vperp_magnitude = np.sqrt(ux_pert_perp**2+uy_pert_perp**2+uz_pert_perp**2)
    
    delta_Bperp_magnitude = np.sqrt(Bx_pert_perp**2+By_pert_perp**2+Bz_pert_perp**2)
    
    delta_v_alfven = delta_Bperp_magnitude/np.sqrt(mu_0*(delta_density_data['density_pert']*1e6))
    
    energy_df = pd.DataFrame({'delta_dot_prod': delta_dot_prod , 'Helicity': Helicity, 'delta_energy': delta_energy_norm, 'norm_Helicity': norm_Helicity, 'norm_residual_energy': residual_energy_Norm, 'v_Alfven': v_Alfven, 'cos_theta':cos_theta, 'delta_vperp_squared_norm': delta_vperp_squared_norm, 'delta_Bperp_squared_norm': delta_Bperp_squared_norm, 'norm_helicity_num': norm_Helicity_num})  
    print('Combine with z_mag  and R array ...')
    
    #filename = '/home/mtfranciscovich/Juno-codes/reduced_inbound_1s_pickles/reduced_orbit_' +str(i) +'_1s.pkl'
    #picklefile = open(filename,'rb')
    #mag_data_mag_frame = pickle.load(picklefile)
    z_mag_info = z_mag_data['Z_MAG']
    Rj_km = 7.14e4
    R_info = np.sqrt(z_mag_data['X_JSS']**2+z_mag_data['Y_JSS']**2)/Rj_km    
    energy_df['Z_MAG'] = z_mag_info
    energy_df['R_cyl_jss'] = R_info
    
    energy_df = energy_df.dropna()
    mean_energy_data = pd.DataFrame({'MEAN_delta_dot_prod': [], 'MEAN_Helicity': [], 'MEAN_delta_energy': [], 'MEAN_norm_Helicity': [], 'MEAN_norm_residual_energy': [], 'MEAN_cos_theta': []})

    finish_datetime = (energy_df.index[-1]
- timedelta(minutes=np.floor(window_size/2)))
    for datetime_index in energy_df.index:
        start_datetime = datetime_index
        end_datetime = start_datetime + timedelta(minutes=window_size)
        mean_datetime_index = pd.DatetimeIndex([
        (start_datetime + timedelta(minutes=round(window_size/2))).isoformat()
        ])
        temp_mean_delta_dot_prod = np.nanmean(energy_df[start_datetime.isoformat(): end_datetime.isoformat()].delta_dot_prod)
        temp_mean_Helicity = np.nanmean(energy_df[start_datetime.isoformat(): end_datetime.isoformat()].Helicity)
        temp_mean_delta_energy = np.nanmean(energy_df[start_datetime.isoformat(): end_datetime.isoformat()].delta_energy)
        temp_mean_norm_Helicity = np.nanmean(energy_df[start_datetime.isoformat(): end_datetime.isoformat()].norm_Helicity)
        temp_mean_norm_residual_energy = np.nanmean(energy_df[start_datetime.isoformat(): end_datetime.isoformat()].norm_residual_energy)
        temp_mean_cos_theta = np.nanmean(energy_df[start_datetime.isoformat(): end_datetime.isoformat()].cos_theta)
        
        
        mean_array_to_concat = pd.DataFrame(
        {'MEAN_delta_dot_prod': temp_mean_delta_dot_prod,
            'MEAN_Helicity': temp_mean_Helicity,
            'MEAN_delta_energy' : temp_mean_delta_energy,
            'MEAN_norm_Helicity' : temp_mean_norm_Helicity,
            'MEAN_norm_residual_energy': temp_mean_norm_residual_energy,
            'MEAN_cos_theta': temp_mean_cos_theta,
            }, index=mean_datetime_index)
        mean_energy_data = pd.concat([mean_energy_data, mean_array_to_concat])
    
        if mean_datetime_index == finish_datetime:
            break
    energy_df = energy_df[mean_energy_data.index[0].isoformat(): 
                            mean_energy_data.index[-1].isoformat()]
    energy_df = pd.concat([energy_df, mean_energy_data], axis=1)

    if save_pickles:
        energy_df.to_pickle('/home/mtfranciscovich/Juno-codes/energy_pickles_jso_0821/energy_df_orbit_' + str(i) + '.pkl')
# Out:
# 1.2566370614359173e-06
# grabbing mean density
# grabbing mean mag orbit 23
# Index(['BX', 'BY', 'BZ', 'X', 'Y', 'Z', 'R', 'BR', 'BTHETA', 'BPHI', 'Z_MAG',
#        'BX_JSS', 'BY_JSS', 'BZ_JSS', 'UNITZ_X', 'UNITZ_Y', 'UNITZ_Z', 'X_JSS',
#        'Y_JSS', 'Z_JSS'],
#       dtype='object')
# grabbing orbit 23
# grabbing total mag orbit 23
# grabbing mean v orbit 23
# grabbing total v orbit 23
# cleaning mean density
# Calculating dot prod and helicity...
# Combine with z_mag  and R array ...
